# %%
 # %%bash
 wget https://storage.googleapis.com/vit_models/imagenet21k/R50%2BViT-B_16.npz &&
 mkdir -p ../model/vit_checkpoint/imagenet21k &&
 mv R50+ViT-B_16.npz ../model/vit_checkpoint/imagenet21k/R50%2BViT-B_16.npz
# Out:
# --2022-05-16 07:30:23--  https://storage.googleapis.com/vit_models/imagenet21k/R50%2BViT-B_16.npz
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.97.128, 142.251.107.128, 108.177.11.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.97.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 461217452 (440M) [application/octet-stream]
# Saving to: ‘R50+ViT-B_16.npz’
#
#      0K .......... .......... .......... .......... ..........  0% 25.5M 17s
#     50K .......... .......... .......... .......... ..........  0%  119M 10s
#    100K .......... .......... .......... .......... ..........  0%  105M 8s
#    150K .......... .......... .......... .......... ..........  0%  114M 7s
#    200K .......... .......... .......... .......... ..........  0% 34.5M 8s
#    250K .......... .......... .......... .......... ..........  0% 21.8M 10s
#    300K .......... .......... .......... .......... ..........  0% 23.6M 11s
#    350K .......... .......... .......... .......... ..........  0% 33.3M 12s
#    400K .......... .......... .......... .......... ..........  0% 37.6M 12s
#    450K .......... .......... .......... .......... ..........  0% 48.4M 11s
#    500K .......... .......... .......... .......... ..........  0% 25.7M 12s
#    550K .......... .......... .......... .......... ..........  0% 28.1M 12s
#    600K .......... .......... .......... .......... ..........  0% 24.8M 13s
#    650K .......... .......... .......... .......... ..........  0% 28.9M 13s
#    700K .......... .......... .......... .......... ..........  0% 34.4M 13s
#    750K .......... .......... .......... .......... ..........  0% 26.3M 13s
#    800K .......... .......... .......... .......... ..........  0% 25.4M 13s
#    850K .......... .......... .......... .......... ..........  0% 31.3M 13s
#    900K .......... .......... .......... .......... ..........  0% 29.6M 13s
#    950K .......... .......... .......... .......... ..........  0% 30.6M 13s
#   1000K .......... .......... .......... .......... ..........  0% 29.6M 14s
#   1050K .......... .......... .......... .......... ..........  0% 41.5M 13s
#   1100K .......... .......... .......... .......... ..........  0% 38.2M 13s
#   1150K .......... .......... .......... .......... ..........  0% 30.9M 13s
#   1200K .......... .......... .......... .......... ..........  0% 43.8M 13s
#   1250K .......... .......... .......... .......... ..........  0%  140M 13s
#   1300K .......... .......... .......... .......... ..........  0%  176M 12s
#   1350K .......... .......... .......... .......... ..........  0%  147M 12s
#   1400K .......... .......... .......... .......... ..........  0%  123M 12s
#   1450K .......... .......... .......... .......... ..........  0%  224M 11s
#   1500K .......... .......... .......... .......... ..........  0%  138M 11s
#   1550K .......... .......... .......... .......... ..........  0%  160M 11s
#   1600K .......... .......... .......... .......... ..........  0%  224M 11s
#   1650K .......... .......... .......... .......... ..........  0%  140M 10s
#   1700K .......... .......... .......... .......... ..........  0%  181M 10s
#   1750K .......... .......... .......... .......... ..........  0%  188M 10s
#   1800K .......... .......... .......... .......... ..........  0%  198M 10s
#   1850K .......... .......... .......... .......... ..........  0%  164M 10s
#   1900K .......... .......... .......... .......... ..........  0%  219M 9s
#   1950K .......... .......... .......... .......... ..........  0%  206M 9s
#   2000K .......... .......... .......... .......... ..........  0%  225M 9s
#   2050K .......... .......... .......... .......... ..........  0% 84.6M 9s
#   2100K .......... .......... .......... .......... ..........  0% 55.5M 9s
#   2150K .......... .......... .......... .......... ..........  0% 63.6M 9s
#   2200K .......... .......... .......... .......... ..........  0%  124M 9s
#   2250K .......... .......... .......... .......... ..........  0%  126M 9s
#   2300K .......... .......... .......... .......... ..........  0%  101M 9s
#   2350K .......... .......... .......... .......... ..........  0% 64.5M 9s
#   2400K .......... .......... .......... .......... ..........  0% 42.3M 9s
#   2450K .......... .......... .......... .......... ..........  0% 43.1M 9s
#   2500K .......... .......... .......... .......... ..........  0% 45.1M 9s
#   2550K .......... .......... .......... .......... ..........  0% 63.1M 9s
#   2600K .......... .......... .......... .......... ..........  0% 46.8M 9s
#   2650K .......... .......... .......... .......... ..........  0% 58.9M 9s
#   2700K .......... .......... .......... .......... ..........  0%  184M 8s
#   2750K .......... .......... .......... .......... ..........  0% 69.3M 8s
#   2800K .......... .......... .......... .......... ..........  0%  132M 8s
#   2850K .......... .......... .......... .......... ..........  0%  109M 8s
#   2900K .......... .......... .......... .......... ..........  0%  161M 8s
#   2950K .......... .......... .......... .......... ..........  0%  146M 8s
#   3000K .......... .......... .......... .......... ..........  0%  223M 8s
#   3050K .......... .......... .......... .......... ..........  0%  211M 8s
#   3100K .......... .......... .......... .......... ..........  0%  227M 8s
#   3150K .......... .......... .......... .......... ..........  0%  187M 8s
#   3200K .......... .......... .......... .......... ..........  0%  218M 8s
#   3250K .......... .......... .......... .......... ..........  0%  229M 8s
#   3300K .......... .......... .......... .......... ..........  0%  209M 7s
#   3350K .......... .......... .......... .......... ..........  0%  211M 7s
#   3400K .......... .......... .......... .......... ..........  0%  224M 7s
#   3450K .......... .......... .......... .......... ..........  0%  227M 7s
#   3500K .......... .......... .......... .......... ..........  0%  219M 7s
#   3550K .......... .......... .......... .......... ..........  0%  185M 7s
#   3600K .......... .......... .......... .......... ..........  0%  218M 7s
#   3650K .......... .......... .......... .......... ..........  0%  207M 7s
#   3700K .......... .......... .......... .......... ..........  0%  217M 7s
#   3750K .......... .......... .......... .......... ..........  0%  192M 7s
#   3800K .......... .......... .......... .......... ..........  0%  219M 7s
#   3850K .......... .......... .......... .......... ..........  0%  217M 7s
#   3900K .......... .......... .......... .......... ..........  0%  201M 7s
#   3950K .......... .......... .......... .......... ..........  0% 41.2M 7s
#   4000K .......... .......... .......... .......... ..........  0% 45.8M 7s
#   4050K .......... .......... .......... .......... ..........  0%  513K 17s
#   4100K .......... .......... .......... .......... ..........  0% 27.1M 17s
#   4150K .......... .......... .......... .......... ..........  0% 26.1M 17s
#   4200K .......... .......... .......... .......... ..........  0% 29.2M 17s
#   4250K .......... .......... .......... .......... ..........  0% 45.1M 17s
#   4300K .......... .......... .......... .......... ..........  0% 43.3M 17s
#   4350K .......... .......... .......... .......... ..........  0% 49.9M 17s
#   4400K .......... .......... .......... .......... ..........  0% 43.5M 17s
#   4450K .......... .......... .......... .......... ..........  0% 9.18M 17s
#   4500K .......... .......... .......... .......... ..........  1%  157M 17s
#   4550K .......... .......... .......... .......... ..........  1%  179M 17s
#   4600K .......... .......... .......... .......... ..........  1% 32.1M 17s
#   4650K .......... .......... .......... .......... ..........  1%  151M 17s
#   4700K .......... .......... .......... .......... ..........  1%  219M 16s
#   4750K .......... .......... .......... .......... ..........  1%  242M 16s
#   4800K .......... .......... .......... .......... ..........  1%  169M 16s
#   4850K .......... .......... .......... .......... ..........  1%  286M 16s
#   4900K .......... .......... .......... .......... ..........  1%  228M 16s
#   4950K .......... .......... .......... .......... ..........  1%  236M 16s
#   5000K .......... .......... .......... .......... ..........  1%  180M 16s
#   5050K .......... .......... .......... .......... ..........  1%  321M 15s
#   5100K .......... .......... .......... .......... ..........  1%  364M 15s
#   5150K .......... .......... .......... .......... ..........  1% 30.4M 15s
#   5200K .......... .......... .......... .......... ..........  1%  131M 15s
#   5250K .......... .......... .......... .......... ..........  1%  123M 15s
#   5300K .......... .......... .......... .......... ..........  1%  175M 15s
#   5350K .......... .......... .......... .......... ..........  1%  162M 15s
#   5400K .......... .......... .......... .......... ..........  1% 91.7M 15s
#   5450K .......... .......... .......... .......... ..........  1%  194M 15s
#   5500K .......... .......... .......... .......... ..........  1%  198M 15s
#   5550K .......... .......... .......... .......... ..........  1% 83.9M 14s
#   5600K .......... .......... .......... .......... ..........  1% 45.2M 14s
#   5650K .......... .......... .......... .......... ..........  1% 79.7M 14s
#   5700K .......... .......... .......... .......... ..........  1%  212M 14s
#   5750K .......... .......... .......... .......... ..........  1% 54.2M 14s
#   5800K .......... .......... .......... .......... ..........  1%  225M 14s
#   5850K .......... .......... .......... .......... ..........  1%  256M 14s
#   5900K .......... .......... .......... .......... ..........  1%  227M 14s
#   5950K .......... .......... .......... .......... ..........  1%  247M 14s
#   6000K .......... .......... .......... .......... ..........  1%  137M 14s
#   6050K .......... .......... .......... .......... ..........  1%  223M 14s
#   6100K .......... .......... .......... .......... ..........  1%  219M 13s
#   6150K .......... .......... .......... .......... ..........  1%  222M 13s
#   6200K .......... .......... .......... .......... ..........  1%  221M 13s
#   6250K .......... .......... .......... .......... ..........  1%  257M 13s
#   6300K .......... .......... .......... .......... ..........  1%  251M 13s
#   6350K .......... .......... .......... .......... ..........  1%  224M 13s
#   6400K .......... .......... .......... .......... ..........  1%  199M 13s
#   6450K .......... .......... .......... .......... ..........  1%  263M 13s
#   6500K .......... .......... .......... .......... ..........  1%  255M 13s
#   6550K .......... .......... .......... .......... ..........  1%  253M 13s
#   6600K .......... .......... .......... .......... ..........  1%  225M 13s
#   6650K .......... .......... .......... .......... ..........  1% 43.5M 13s
#   6700K .......... .......... .......... .......... ..........  1% 49.0M 13s
#   6750K .......... .......... .......... .......... ..........  1% 48.8M 12s
#   6800K .......... .......... .......... .......... ..........  1% 32.7M 12s
#   6850K .......... .......... .......... .......... ..........  1% 82.0M 12s
#   6900K .......... .......... .......... .......... ..........  1%  209M 12s
#   6950K .......... .......... .......... .......... ..........  1%  106M 12s
#   7000K .......... .......... .......... .......... ..........  1% 41.4M 12s
#   7050K .......... .......... .......... .......... ..........  1% 81.3M 12s
#   7100K .......... .......... .......... .......... ..........  1% 94.1M 12s
#   7150K .......... .......... .......... .......... ..........  1% 52.5M 12s
#   7200K .......... .......... .......... .......... ..........  1% 37.0M 12s
#   7250K .......... .......... .......... .......... ..........  1% 42.5M 12s
#   7300K .......... .......... .......... .......... ..........  1%  188M 12s
#   7350K .......... .......... .......... .......... ..........  1%  207M 12s
#   7400K .......... .......... .......... .......... ..........  1%  204M 12s
#   7450K .......... .......... .......... .......... ..........  1%  247M 12s
#   7500K .......... .......... .......... .......... ..........  1%  237M 12s
#   7550K .......... .......... .......... .......... ..........  1%  276M 12s
#   7600K .......... .......... .......... .......... ..........  1%  224M 12s
#   7650K .......... .......... .......... .......... ..........  1%  257M 12s
#   7700K .......... .......... .......... .......... ..........  1%  281M 12s
#   7750K .......... .......... .......... .......... ..........  1%  254M 11s
#   7800K .......... .......... .......... .......... ..........  1%  214M 11s
#   7850K .......... .......... .......... .......... ..........  1%  245M 11s
#   7900K .......... .......... .......... .......... ..........  1%  265M 11s
#   7950K .......... .......... .......... .......... ..........  1%  259M 11s
#   8000K .......... .......... .......... .......... ..........  1%  213M 11s
#   8050K .......... .......... .......... .......... ..........  1%  259M 11s
#   8100K .......... .......... .......... .......... ..........  1%  229M 11s
#   8150K .......... .......... .......... .......... ..........  1% 4.52M 12s
#   8200K .......... .......... .......... .......... ..........  1% 66.4M 12s
#   8250K .......... .......... .......... .......... ..........  1%  122M 11s
#   8300K .......... .......... .......... .......... ..........  1% 64.8M 11s
#   8350K .......... .......... .......... .......... ..........  1% 55.3M 11s
#   8400K .......... .......... .......... .......... ..........  1% 23.0M 11s
#   8450K .......... .......... .......... .......... ..........  1% 32.0M 11s
#   8500K .......... .......... .......... .......... ..........  1% 36.5M 11s
#   8550K .......... .......... .......... .......... ..........  1% 40.3M 11s
#   8600K .......... .......... .......... .......... ..........  1% 37.4M 11s
#   8650K .......... .......... .......... .......... ..........  1% 45.5M 11s
#   8700K .......... .......... .......... .......... ..........  1% 76.6M 11s
#   8750K .......... .......... .......... .......... ..........  1%  203M 11s
#   8800K .......... .......... .......... .......... ..........  1%  118M 11s
#   8850K .......... .......... .......... .......... ..........  1%  170M 11s
#   8900K .......... .......... .......... .......... ..........  1%  191M 11s
#   8950K .......... .......... .......... .......... ..........  1%  161M 11s
#   9000K .......... .......... .......... .......... ..........  2%  183M 11s
#   9050K .......... .......... .......... .......... ..........  2%  196M 11s
#   9100K .......... .......... .......... .......... ..........  2%  153M 11s
#   9150K .......... .......... .......... .......... ..........  2%  197M 11s
#   9200K .......... .......... .......... .......... ..........  2%  175M 11s
#   9250K .......... .......... .......... .......... ..........  2%  242M 11s
#   9300K .......... .......... .......... .......... ..........  2%  181M 11s
#   9350K .......... .......... .......... .......... ..........  2%  245M 11s
#   9400K .......... .......... .......... .......... ..........  2%  131M 11s
#   9450K .......... .......... .......... .......... ..........  2% 92.0M 11s
#   9500K .......... .......... .......... .......... ..........  2% 46.5M 11s
#   9550K .......... .......... .......... .......... ..........  2% 48.9M 11s
#   9600K .......... .......... .......... .......... ..........  2% 54.4M 11s
#   9650K .......... .......... .......... .......... ..........  2% 40.0M 11s
#   9700K .......... .......... .......... .......... ..........  2% 41.8M 11s
#   9750K .......... .......... .......... .......... ..........  2% 40.7M 11s
#   9800K .......... .......... .......... .......... ..........  2% 38.3M 11s
#   9850K .......... .......... .......... .......... ..........  2% 41.3M 11s
#   9900K .......... .......... .......... .......... ..........  2% 49.2M 11s
#   9950K .......... .......... .......... .......... ..........  2% 45.0M 11s
#  10000K .......... .......... .......... .......... ..........  2% 39.2M 11s
#  10050K .......... .......... .......... .......... ..........  2% 65.3M 11s
#  10100K .......... .......... .......... .......... ..........  2%  152M 11s
#  10150K .......... .......... .......... .......... ..........  2%  237M 11s
#  10200K .......... .......... .......... .......... ..........  2%  184M 11s
#  10250K .......... .......... .......... .......... ..........  2%  295M 10s
#  10300K .......... .......... .......... .......... ..........  2%  214M 10s
#  10350K .......... .......... .......... .......... ..........  2%  318M 10s
#  10400K .......... .......... .......... .......... ..........  2%  338M 10s
#  10450K .......... .......... .......... .......... ..........  2%  322M 10s
#  10500K .......... .......... .......... .......... ..........  2%  226M 10s
#  10550K .......... .......... .......... .......... ..........  2%  371M 10s
#  10600K .......... .......... .......... .......... ..........  2%  238M 10s
#  10650K .......... .......... .......... .......... ..........  2%  219M 10s
#  10700K .......... .......... .......... .......... ..........  2%  303M 10s
#  10750K .......... .......... .......... .......... ..........  2%  205M 10s
#  10800K .......... .......... .......... .......... ..........  2%  140M 10s
#  10850K .......... .......... .......... .......... ..........  2%  194M 10s
#  10900K .......... .......... .......... .......... ..........  2%  297M 10s
#  10950K .......... .......... .......... .......... ..........  2%  277M 10s
#  11000K .......... .......... .......... .......... ..........  2%  267M 10s
#  11050K .......... .......... .......... .......... ..........  2%  149M 10s
#  11100K .......... .......... .......... .......... ..........  2%  169M 10s
#  11150K .......... .......... .......... .......... ..........  2% 69.8M 10s
#  11200K .......... .......... .......... .......... ..........  2%  112M 10s
#  11250K .......... .......... .......... .......... ..........  2% 46.5M 10s
#  11300K .......... .......... .......... .......... ..........  2% 43.2M 10s
#  11350K .......... .......... .......... .......... ..........  2%  129M 10s
#  11400K .......... .......... .......... .......... ..........  2% 59.6M 10s
#  11450K .......... .......... .......... .......... ..........  2% 54.6M 10s
#  11500K .......... .......... .......... .......... ..........  2% 35.1M 10s
#  11550K .......... .......... .......... .......... ..........  2% 43.7M 10s
#  11600K .......... .......... .......... .......... ..........  2%  140M 10s
#  11650K .......... .......... .......... .......... ..........  2% 62.4M 10s
#  11700K .......... .......... .......... .......... ..........  2% 46.8M 10s
#  11750K .......... .......... .......... .......... ..........  2% 37.0M 10s
#  11800K .......... .......... .......... .......... ..........  2% 38.9M 10s
#  11850K .......... .......... .......... .......... ..........  2% 55.0M 10s
#  11900K .......... .......... .......... .......... ..........  2%  215M 10s
#  11950K .......... .......... .......... .......... ..........  2%  186M 10s
#  12000K .......... .......... .......... .......... ..........  2%  196M 10s
#  12050K .......... .......... .......... .......... ..........  2%  131M 10s
#  12100K .......... .......... .......... .......... ..........  2%  296M 9s
#  12150K .......... .......... .......... .......... ..........  2%  366M 9s
#  12200K .......... .......... .......... .......... ..........  2%  184M 9s
#  12250K .......... .......... .......... .......... ..........  2%  360M 9s
#  12300K .......... .......... .......... .......... ..........  2%  203M 9s
#  12350K .......... .......... .......... .......... ..........  2%  159M 9s
#  12400K .......... .......... .......... .......... ..........  2%  186M 9s
#  12450K .......... .......... .......... .......... ..........  2%  204M 9s
#  12500K .......... .......... .......... .......... ..........  2%  193M 9s
#  12550K .......... .......... .......... .......... ..........  2%  154M 9s
#  12600K .......... .......... .......... .......... ..........  2%  176M 9s
#  12650K .......... .......... .......... .......... ..........  2%  243M 9s
#  12700K .......... .......... .......... .......... ..........  2%  225M 9s
#  12750K .......... .......... .......... .......... ..........  2%  248M 9s
#  12800K .......... .......... .......... .......... ..........  2%  140M 9s
#  12850K .......... .......... .......... .......... ..........  2%  245M 9s
#  12900K .......... .......... .......... .......... ..........  2%  243M 9s
#  12950K .......... .......... .......... .......... ..........  2%  233M 9s
#  13000K .......... .......... .......... .......... ..........  2%  213M 9s
#  13050K .......... .......... .......... .......... ..........  2% 35.0M 9s
#  13100K .......... .......... .......... .......... ..........  2% 47.5M 9s
#  13150K .......... .......... .......... .......... ..........  2% 46.8M 9s
#  13200K .......... .......... .......... .......... ..........  2% 18.4M 9s
#  13250K .......... .......... .......... .......... ..........  2%  204M 9s
#  13300K .......... .......... .......... .......... ..........  2%  258M 9s
#  13350K .......... .......... .......... .......... ..........  2%  273M 9s
#  13400K .......... .......... .......... .......... ..........  2%  231M 9s
#  13450K .......... .......... .......... .......... ..........  2%  243M 9s
#  13500K .......... .......... .......... .......... ..........  3%  263M 9s
#  13550K .......... .......... .......... .......... ..........  3%  291M 9s
#  13600K .......... .......... .......... .......... ..........  3%  226M 9s
#  13650K .......... .......... .......... .......... ..........  3%  277M 9s
#  13700K .......... .......... .......... .......... ..........  3%  149M 9s
#  13750K .......... .......... .......... .......... ..........  3%  256M 9s
#  13800K .......... .......... .......... .......... ..........  3%  233M 9s
#  13850K .......... .......... .......... .......... ..........  3%  272M 9s
#  13900K .......... .......... .......... .......... ..........  3%  256M 9s
#  13950K .......... .......... .......... .......... ..........  3%  226M 9s
#  14000K .......... .......... .......... .......... ..........  3%  221M 9s
#  14050K .......... .......... .......... .......... ..........  3%  216M 9s
#  14100K .......... .......... .......... .......... ..........  3%  214M 9s
#  14150K .......... .......... .......... .......... ..........  3%  146M 9s
#  14200K .......... .......... .......... .......... ..........  3%  190M 9s
#  14250K .......... .......... .......... .......... ..........  3%  191M 8s
#  14300K .......... .......... .......... .......... ..........  3%  172M 8s
#  14350K .......... .......... .......... .......... ..........  3% 33.1M 8s
#  14400K .......... .......... .......... .......... ..........  3% 39.0M 8s
#  14450K .......... .......... .......... .......... ..........  3% 45.2M 8s
#  14500K .......... .......... .......... .......... ..........  3% 39.4M 8s
#  14550K .......... .......... .......... .......... ..........  3% 43.1M 8s
#  14600K .......... .......... .......... .......... ..........  3% 38.4M 9s
#  14650K .......... .......... .......... .......... ..........  3% 53.3M 9s
#  14700K .......... .......... .......... .......... ..........  3%  199M 8s
#  14750K .......... .......... .......... .......... ..........  3%  221M 8s
#  14800K .......... .......... .......... .......... ..........  3%  157M 8s
#  14850K .......... .......... .......... .......... ..........  3%  209M 8s
#  14900K .......... .......... .......... .......... ..........  3%  247M 8s
#  14950K .......... .......... .......... .......... ..........  3%  220M 8s
#  15000K .......... .......... .......... .......... ..........  3%  182M 8s
#  15050K .......... .......... .......... .......... ..........  3%  190M 8s
#  15100K .......... .......... .......... .......... ..........  3%  207M 8s
#  15150K .......... .......... .......... .......... ..........  3%  240M 8s
#  15200K .......... .......... .......... .......... ..........  3%  199M 8s
#  15250K .......... .......... .......... .......... ..........  3%  187M 8s
#  15300K .......... .......... .......... .......... ..........  3%  231M 8s
#  15350K .......... .......... .......... .......... ..........  3%  185M 8s
#  15400K .......... .......... .......... .......... ..........  3%  164M 8s
#  15450K .......... .......... .......... .......... ..........  3%  222M 8s
#  15500K .......... .......... .......... .......... ..........  3%  215M 8s
#  15550K .......... .......... .......... .......... ..........  3%  204M 8s
#  15600K .......... .......... .......... .......... ..........  3%  175M 8s
#  15650K .......... .......... .......... .......... ..........  3% 40.3M 8s
#  15700K .......... .......... .......... .......... ..........  3% 45.8M 8s
#  15750K .......... .......... .......... .......... ..........  3% 40.4M 8s
#  15800K .......... .......... .......... .......... ..........  3% 39.0M 8s
#  15850K .......... .......... .......... .......... ..........  3% 43.4M 8s
#  15900K .......... .......... .......... .......... ..........  3% 42.1M 8s
#  15950K .......... .......... .......... .......... ..........  3% 52.5M 8s
#  16000K .......... .......... .......... .......... ..........  3% 39.0M 8s
#  16050K .......... .......... .......... .......... ..........  3% 47.1M 8s
#  16100K .......... .......... .......... .......... ..........  3% 47.1M 8s
#  16150K .......... .......... .......... .......... ..........  3% 47.4M 8s
#  16200K .......... .......... .......... .......... ..........  3% 38.4M 8s
#  16250K .......... .......... .......... .......... ..........  3% 38.8M 8s
#  16300K .......... .......... .......... .......... ..........  3% 54.1M 8s
#  16350K .......... .......... .......... .......... ..........  3%  216M 8s
#  16400K .......... .......... .......... .......... ..........  3%  170M 8s
#  16450K .......... .......... .......... .......... ..........  3%  242M 8s
#  16500K .......... .......... .......... .......... ..........  3%  221M 8s
#  16550K .......... .......... .......... .......... ..........  3%  197M 8s
#  16600K .......... .......... .......... .......... ..........  3%  165M 8s
#  16650K .......... .......... .......... .......... ..........  3%  227M 8s
#  16700K .......... .......... .......... .......... ..........  3%  252M 8s
#  16750K .......... .......... .......... .......... ..........  3%  230M 8s
#  16800K .......... .......... .......... .......... ..........  3%  152M 8s
#  16850K .......... .......... .......... .......... ..........  3%  234M 8s
#  16900K .......... .......... .......... .......... ..........  3%  223M 8s
#  16950K .......... .......... .......... .......... ..........  3%  219M 8s
#  17000K .......... .......... .......... .......... ..........  3%  152M 8s
#  17050K .......... .......... .......... .......... ..........  3%  228M 8s
#  17100K .......... .......... .......... .......... ..........  3%  257M 8s
#  17150K .......... .......... .......... .......... ..........  3%  213M 8s
#  17200K .......... .......... .......... .......... ..........  3%  115M 8s
#  17250K .......... .......... .......... .......... ..........  3%  204M 8s
#  17300K .......... .......... .......... .......... ..........  3%  219M 8s
#  17350K .......... .......... .......... .......... ..........  3%  202M 8s
#  17400K .......... .......... .......... .......... ..........  3%  172M 8s
#  17450K .......... .......... .......... .......... ..........  3%  246M 8s
#  17500K .......... .......... .......... .......... ..........  3%  190M 8s
#  17550K .......... .......... .......... .......... ..........  3%  260M 8s
#  17600K .......... .......... .......... .......... ..........  3% 78.6M 8s
#  17650K .......... .......... .......... .......... ..........  3% 44.8M 8s
#  17700K .......... .......... .......... .......... ..........  3% 47.6M 8s
#  17750K .......... .......... .......... .......... ..........  3% 50.5M 8s
#  17800K .......... .......... .......... .......... ..........  3% 44.9M 8s
#  17850K .......... .......... .......... .......... ..........  3% 42.3M 8s
#  17900K .......... .......... .......... .......... ..........  3% 35.5M 8s
#  17950K .......... .......... .......... .......... ..........  3% 46.1M 8s
#  18000K .......... .......... .......... .......... ..........  4% 41.8M 8s
#  18050K .......... .......... .......... .......... ..........  4% 56.1M 8s
#  18100K .......... .......... .......... .......... ..........  4%  105M 8s
#  18150K .......... .......... .......... .......... ..........  4%  261M 8s
#  18200K .......... .......... .......... .......... ..........  4%  168M 8s
#  18250K .......... .......... .......... .......... ..........  4%  255M 8s
#  18300K .......... .......... .......... .......... ..........  4%  232M 8s
#  18350K .......... .......... .......... .......... ..........  4%  232M 8s
#  18400K .......... .......... .......... .......... ..........  4%  173M 8s
#  18450K .......... .......... .......... .......... ..........  4%  234M 8s
#  18500K .......... .......... .......... .......... ..........  4% 13.5M 8s
#  18550K .......... .......... .......... .......... ..........  4% 48.5M 8s
#  18600K .......... .......... .......... .......... ..........  4% 34.7M 8s
#  18650K .......... .......... .......... .......... ..........  4% 43.6M 8s
#  18700K .......... .......... .......... .......... ..........  4% 45.2M 8s
#  18750K .......... .......... .......... .......... ..........  4% 36.0M 8s
#  18800K .......... .......... .......... .......... ..........  4% 36.3M 8s
#  18850K .......... .......... .......... .......... ..........  4%  117M 8s
#  18900K .......... .......... .......... .......... ..........  4%  245M 8s
#  18950K .......... .......... .......... .......... ..........  4% 85.5M 8s
#  19000K .......... .......... .......... .......... ..........  4% 40.0M 8s
#  19050K .......... .......... .......... .......... ..........  4% 66.9M 8s
#  19100K .......... .......... .......... .......... ..........  4%  230M 8s
#  19150K .......... .......... .......... .......... ..........  4%  220M 8s
#  19200K .......... .......... .......... .......... ..........  4%  167M 8s
#  19250K .......... .......... .......... .......... ..........  4%  263M 8s
#  19300K .......... .......... .......... .......... ..........  4%  244M 8s
#  19350K .......... .......... .......... .......... ..........  4%  244M 8s
#  19400K .......... .......... .......... .......... ..........  4%  240M 8s
#  19450K .......... .......... .......... .......... ..........  4%  214M 8s
#  19500K .......... .......... .......... .......... ..........  4%  302M 8s
#  19550K .......... .......... .......... .......... ..........  4%  278M 8s
#  19600K .......... .......... .......... .......... ..........  4%  200M 8s
#  19650K .......... .......... .......... .......... ..........  4%  249M 7s
#  19700K .......... .......... .......... .......... ..........  4%  217M 7s
#  19750K .......... .......... .......... .......... ..........  4%  305M 7s
#  19800K .......... .......... .......... .......... ..........  4%  214M 7s
#  19850K .......... .......... .......... .......... ..........  4%  227M 7s
#  19900K .......... .......... .......... .......... ..........  4%  253M 7s
#  19950K .......... .......... .......... .......... ..........  4%  194M 7s
#  20000K .......... .......... .......... .......... ..........  4%  236M 7s
#  20050K .......... .......... .......... .......... ..........  4%  246M 7s
#  20100K .......... .......... .......... .......... ..........  4%  199M 7s
#  20150K .......... .......... .......... .......... ..........  4%  244M 7s
#  20200K .......... .......... .......... .......... ..........  4% 40.6M 7s
#  20250K .......... .......... .......... .......... ..........  4% 43.9M 7s
#  20300K .......... .......... .......... .......... ..........  4% 50.9M 7s
#  20350K .......... .......... .......... .......... ..........  4% 42.6M 7s
#  20400K .......... .......... .......... .......... ..........  4% 27.3M 7s
#  20450K .......... .......... .......... .......... ..........  4% 16.1M 7s
#  20500K .......... .......... .......... .......... ..........  4%  157M 7s
#  20550K .......... .......... .......... .......... ..........  4%  213M 7s
#  20600K .......... .......... .......... .......... ..........  4% 87.3M 7s
#  20650K .......... .......... .......... .......... ..........  4%  211M 7s
#  20700K .......... .......... .......... .......... ..........  4%  184M 7s
#  20750K .......... .......... .......... .......... ..........  4%  168M 7s
#  20800K .......... .......... .......... .......... ..........  4%  146M 7s
#  20850K .......... .......... .......... .......... ..........  4%  187M 7s
#  20900K .......... .......... .......... .......... ..........  4%  186M 7s
#  20950K .......... .......... .......... .......... ..........  4%  196M 7s
#  21000K .......... .......... .......... .......... ..........  4%  171M 7s
#  21050K .......... .......... .......... .......... ..........  4%  194M 7s
#  21100K .......... .......... .......... .......... ..........  4%  183M 7s
#  21150K .......... .......... .......... .......... ..........  4%  209M 7s
#  21200K .......... .......... .......... .......... ..........  4%  228M 7s
#  21250K .......... .......... .......... .......... ..........  4%  289M 7s
#  21300K .......... .......... .......... .......... ..........  4%  233M 7s
#  21350K .......... .......... .......... .......... ..........  4%  202M 7s
#  21400K .......... .......... .......... .......... ..........  4%  230M 7s
#  21450K .......... .......... .......... .......... ..........  4%  236M 7s
#  21500K .......... .......... .......... .......... ..........  4%  259M 7s
#  21550K .......... .......... .......... .......... ..........  4%  275M 7s
#  21600K .......... .......... .......... .......... ..........  4%  213M 7s
#  21650K .......... .......... .......... .......... ..........  4%  280M 7s
#  21700K .......... .......... .......... .......... ..........  4%  203M 7s
#  21750K .......... .......... .......... .......... ..........  4%  223M 7s
#  21800K .......... .......... .......... .......... ..........  4%  140M 7s
#  21850K .......... .......... .......... .......... ..........  4%  246M 7s
#  21900K .......... .......... .......... .......... ..........  4%  273M 7s
#  21950K .......... .......... .......... .......... ..........  4%  267M 7s
#  22000K .......... .......... .......... .......... ..........  4%  149M 7s
#  22050K .......... .......... .......... .......... ..........  4% 77.3M 7s
#  22100K .......... .......... .......... .......... ..........  4%  204M 7s
#  22150K .......... .......... .......... .......... ..........  4%  219M 7s
#  22200K .......... .......... .......... .......... ..........  4%  213M 7s
#  22250K .......... .......... .......... .......... ..........  4%  222M 7s
#  22300K .......... .......... .......... .......... ..........  4%  220M 7s
#  22350K .......... .......... .......... .......... ..........  4%  173M 7s
#  22400K .......... .......... .......... .......... ..........  4%  168M 7s
#  22450K .......... .......... .......... .......... ..........  4%  186M 7s
#  22500K .......... .......... .......... .......... ..........  5%  163M 7s
#  22550K .......... .......... .......... .......... ..........  5%  153M 7s
#  22600K .......... .......... .......... .......... ..........  5%  143M 7s
#  22650K .......... .......... .......... .......... ..........  5%  212M 7s
#  22700K .......... .......... .......... .......... ..........  5%  191M 7s
#  22750K .......... .......... .......... .......... ..........  5%  193M 7s
#  22800K .......... .......... .......... .......... ..........  5%  193M 7s
#  22850K .......... .......... .......... .......... ..........  5%  187M 7s
#  22900K .......... .......... .......... .......... ..........  5%  180M 7s
#  22950K .......... .......... .......... .......... ..........  5%  236M 7s
#  23000K .......... .......... .......... .......... ..........  5%  172M 7s
#  23050K .......... .......... .......... .......... ..........  5%  209M 7s
#  23100K .......... .......... .......... .......... ..........  5%  177M 7s
#  23150K .......... .......... .......... .......... ..........  5%  196M 7s
#  23200K .......... .......... .......... .......... ..........  5%  193M 7s
#  23250K .......... .......... .......... .......... ..........  5%  200M 7s
#  23300K .......... .......... .......... .......... ..........  5%  176M 7s
#  23350K .......... .......... .......... .......... ..........  5%  187M 7s
#  23400K .......... .......... .......... .......... ..........  5%  182M 7s
#  23450K .......... .......... .......... .......... ..........  5%  224M 7s
#  23500K .......... .......... .......... .......... ..........  5%  173M 7s
#  23550K .......... .......... .......... .......... ..........  5%  209M 7s
#  23600K .......... .......... .......... .......... ..........  5%  158M 7s
#  23650K .......... .......... .......... .......... ..........  5%  206M 7s
#  23700K .......... .......... .......... .......... ..........  5%  202M 7s
#  23750K .......... .......... .......... .......... ..........  5%  201M 7s
#  23800K .......... .......... .......... .......... ..........  5%  184M 7s
#  23850K .......... .......... .......... .......... ..........  5%  204M 7s
#  23900K .......... .......... .......... .......... ..........  5%  205M 7s
#  23950K .......... .......... .......... .......... ..........  5%  186M 7s
#  24000K .......... .......... .......... .......... ..........  5%  175M 7s
#  24050K .......... .......... .......... .......... ..........  5%  181M 7s
#  24100K .......... .......... .......... .......... ..........  5%  180M 7s
#  24150K .......... .......... .......... .......... ..........  5%  209M 7s
#  24200K .......... .......... .......... .......... ..........  5%  195M 7s
#  24250K .......... .......... .......... .......... ..........  5%  195M 7s
#  24300K .......... .......... .......... .......... ..........  5%  195M 7s
#  24350K .......... .......... .......... .......... ..........  5%  171M 7s
#  24400K .......... .......... .......... .......... ..........  5%  169M 7s
#  24450K .......... .......... .......... .......... ..........  5%  206M 7s
#  24500K .......... .......... .......... .......... ..........  5%  193M 7s
#  24550K .......... .......... .......... .......... ..........  5%  205M 6s
#  24600K .......... .......... .......... .......... ..........  5%  160M 6s
#  24650K .......... .......... .......... .......... ..........  5%  180M 6s
#  24700K .......... .......... .......... .......... ..........  5%  201M 6s
#  24750K .......... .......... .......... .......... ..........  5%  201M 6s
#  24800K .......... .......... .......... .......... ..........  5%  192M 6s
#  24850K .......... .......... .......... .......... ..........  5%  195M 6s
#  24900K .......... .......... .......... .......... ..........  5%  192M 6s
#  24950K .......... .......... .......... .......... ..........  5%  209M 6s
#  25000K .......... .......... .......... .......... ..........  5%  150M 6s
#  25050K .......... .......... .......... .......... ..........  5%  202M 6s
#  25100K .......... .......... .......... .......... ..........  5%  179M 6s
#  25150K .......... .......... .......... .......... ..........  5%  183M 6s
#  25200K .......... .......... .......... .......... ..........  5%  171M 6s
#  25250K .......... .......... .......... .......... ..........  5%  188M 6s
#  25300K .......... .......... .......... .......... ..........  5%  210M 6s
#  25350K .......... .......... .......... .......... ..........  5%  213M 6s
#  25400K .......... .......... .......... .......... ..........  5%  152M 6s
#  25450K .......... .......... .......... .......... ..........  5%  174M 6s
#  25500K .......... .......... .......... .......... ..........  5%  215M 6s
#  25550K .......... .......... .......... .......... ..........  5%  226M 6s
#  25600K .......... .......... .......... .......... ..........  5%  176M 6s
#  25650K .......... .......... .......... .......... ..........  5%  173M 6s
#  25700K .......... .......... .......... .......... ..........  5%  199M 6s
#  25750K .......... .......... .......... .......... ..........  5%  205M 6s
#  25800K .......... .......... .......... .......... ..........  5%  181M 6s
#  25850K .......... .......... .......... .......... ..........  5%  204M 6s
#  25900K .......... .......... .......... .......... ..........  5%  214M 6s
#  25950K .......... .......... .......... .......... ..........  5%  185M 6s
#  26000K .......... .......... .......... .......... ..........  5%  109M 6s
#  26050K .......... .......... .......... .......... ..........  5%  221M 6s
#  26100K .......... .......... .......... .......... ..........  5%  207M 6s
#  26150K .......... .......... .......... .......... ..........  5%  216M 6s
#  26200K .......... .......... .......... .......... ..........  5%  167M 6s
#  26250K .......... .......... .......... .......... ..........  5%  189M 6s
#  26300K .......... .......... .......... .......... ..........  5%  192M 6s
#  26350K .......... .......... .......... .......... ..........  5%  222M 6s
#  26400K .......... .......... .......... .......... ..........  5%  140M 6s
#  26450K .......... .......... .......... .......... ..........  5%  202M 6s
#  26500K .......... .......... .......... .......... ..........  5%  220M 6s
#  26550K .......... .......... .......... .......... ..........  5%  217M 6s
#  26600K .......... .......... .......... .......... ..........  5%  194M 6s
#  26650K .......... .......... .......... .......... ..........  5%  216M 6s
#  26700K .......... .......... .......... .......... ..........  5%  159M 6s
#  26750K .......... .......... .......... .......... ..........  5%  196M 6s
#  26800K .......... .......... .......... .......... ..........  5%  166M 6s
#  26850K .......... .......... .......... .......... ..........  5%  205M 6s
#  26900K .......... .......... .......... .......... ..........  5%  218M 6s
#  26950K .......... .......... .......... .......... ..........  5%  165M 6s
#  27000K .......... .......... .......... .......... ..........  6%  162M 6s
#  27050K .......... .......... .......... .......... ..........  6%  219M 6s
#  27100K .......... .......... .......... .......... ..........  6%  198M 6s
#  27150K .......... .......... .......... .......... ..........  6%  160M 6s
#  27200K .......... .......... .......... .......... ..........  6%  180M 6s
#  27250K .......... .......... .......... .......... ..........  6%  211M 6s
#  27300K .......... .......... .......... .......... ..........  6%  207M 6s
#  27350K .......... .......... .......... .......... ..........  6%  176M 6s
#  27400K .......... .......... .......... .......... ..........  6%  171M 6s
#  27450K .......... .......... .......... .......... ..........  6%  223M 6s
#  27500K .......... .......... .......... .......... ..........  6%  197M 6s
#  27550K .......... .......... .......... .......... ..........  6%  170M 6s
#  27600K .......... .......... .......... .......... ..........  6%  171M 6s
#  27650K .......... .......... .......... .......... ..........  6%  202M 6s
#  27700K .......... .......... .......... .......... ..........  6%  193M 6s
#  27750K .......... .......... .......... .......... ..........  6%  187M 6s
#  27800K .......... .......... .......... .......... ..........  6%  153M 6s
#  27850K .......... .......... .......... .......... ..........  6%  205M 6s
#  27900K .......... .......... .......... .......... ..........  6%  164M 6s
#  27950K .......... .......... .......... .......... ..........  6%  229M 6s
#  28000K .......... .......... .......... .......... ..........  6%  174M 6s
#  28050K .......... .......... .......... .......... ..........  6%  168M 6s
#  28100K .......... .......... .......... .......... ..........  6%  177M 6s
#  28150K .......... .......... .......... .......... ..........  6%  204M 6s
#  28200K .......... .......... .......... .......... ..........  6%  192M 6s
#  28250K .......... .......... .......... .......... ..........  6%  201M 6s
#  28300K .......... .......... .......... .......... ..........  6%  167M 6s
#  28350K .......... .......... .......... .......... ..........  6%  194M 6s
#  28400K .......... .......... .......... .......... ..........  6%  155M 6s
#  28450K .......... .......... .......... .......... ..........  6%  216M 6s
#  28500K .......... .......... .......... .......... ..........  6%  190M 6s
#  28550K .......... .......... .......... .......... ..........  6%  191M 6s
#  28600K .......... .......... .......... .......... ..........  6%  153M 6s
#  28650K .......... .......... .......... .......... ..........  6%  202M 6s
#  28700K .......... .......... .......... .......... ..........  6%  221M 6s
#  28750K .......... .......... .......... .......... ..........  6%  205M 6s
#  28800K .......... .......... .......... .......... ..........  6%  156M 6s
#  28850K .......... .......... .......... .......... ..........  6%  192M 6s
#  28900K .......... .......... .......... .......... ..........  6%  202M 6s
#  28950K .......... .......... .......... .......... ..........  6%  222M 6s
#  29000K .......... .......... .......... .......... ..........  6%  180M 6s
#  29050K .......... .......... .......... .......... ..........  6%  184M 6s
#  29100K .......... .......... .......... .......... ..........  6%  184M 6s
#  29150K .......... .......... .......... .......... ..........  6%  205M 6s
#  29200K .......... .......... .......... .......... ..........  6%  191M 6s
#  29250K .......... .......... .......... .......... ..........  6%  185M 6s
#  29300K .......... .......... .......... .......... ..........  6%  188M 6s
#  29350K .......... .......... .......... .......... ..........  6%  180M 6s
#  29400K .......... .......... .......... .......... ..........  6%  178M 6s
#  29450K .......... .......... .......... .......... ..........  6%  207M 6s
#  29500K .......... .......... .......... .......... ..........  6%  206M 6s
#  29550K .......... .......... .......... .......... ..........  6%  208M 6s
#  29600K .......... .......... .......... .......... ..........  6%  166M 6s
#  29650K .......... .......... .......... .......... ..........  6%  174M 6s
#  29700K .......... .......... .......... .......... ..........  6%  220M 6s
#  29750K .......... .......... .......... .......... ..........  6%  205M 6s
#  29800K .......... .......... .......... .......... ..........  6%  167M 6s
#  29850K .......... .......... .......... .......... ..........  6%  151M 6s
#  29900K .......... .......... .......... .......... ..........  6%  188M 6s
#  29950K .......... .......... .......... .......... ..........  6%  221M 6s
#  30000K .......... .......... .......... .......... ..........  6%  175M 6s
#  30050K .......... .......... .......... .......... ..........  6%  183M 6s
#  30100K .......... .......... .......... .......... ..........  6%  195M 6s
#  30150K .......... .......... .......... .......... ..........  6%  194M 6s
#  30200K .......... .......... .......... .......... ..........  6%  161M 6s
#  30250K .......... .......... .......... .......... ..........  6%  215M 6s
#  30300K .......... .......... .......... .......... ..........  6%  163M 6s
#  30350K .......... .......... .......... .......... ..........  6%  211M 6s
#  30400K .......... .......... .......... .......... ..........  6%  177M 6s
#  30450K .......... .......... .......... .......... ..........  6%  194M 6s
#  30500K .......... .......... .......... .......... ..........  6%  198M 6s
#  30550K .......... .......... .......... .......... ..........  6%  175M 6s
#  30600K .......... .......... .......... .......... ..........  6%  160M 6s
#  30650K .......... .......... .......... .......... ..........  6%  222M 6s
#  30700K .......... .......... .......... .......... ..........  6%  210M 6s
#  30750K .......... .......... .......... .......... ..........  6%  216M 6s
#  30800K .......... .......... .......... .......... ..........  6%  153M 6s
#  30850K .......... .......... .......... .......... ..........  6%  197M 6s
#  30900K .......... .......... .......... .......... ..........  6%  201M 6s
#  30950K .......... .......... .......... .......... ..........  6%  208M 6s
#  31000K .......... .......... .......... .......... ..........  6%  176M 6s
#  31050K .......... .......... .......... .......... ..........  6%  175M 6s
#  31100K .......... .......... .......... .......... ..........  6%  193M 6s
# ...
# 440000K .......... .......... .......... .......... .......... 97%  110M 0s
# 440050K .......... .......... .......... .......... .......... 97%  123M 0s
# 440100K .......... .......... .......... .......... .......... 97%  186M 0s
# 440150K .......... .......... .......... .......... .......... 97%  161M 0s
# 440200K .......... .......... .......... .......... .......... 97%  138M 0s
# 440250K .......... .......... .......... .......... .......... 97%  113M 0s
# 440300K .......... .......... .......... .......... .......... 97%  140M 0s
# 440350K .......... .......... .......... .......... .......... 97%  171M 0s
# 440400K .......... .......... .......... .......... .......... 97%  154M 0s
# 440450K .......... .......... .......... .......... .......... 97%  166M 0s
# 440500K .......... .......... .......... .......... .......... 97%  160M 0s
# 440550K .......... .......... .......... .......... .......... 97%  133M 0s
# 440600K .......... .......... .......... .......... .......... 97% 91.3M 0s
# 440650K .......... .......... .......... .......... .......... 97%  157M 0s
# 440700K .......... .......... .......... .......... .......... 97%  206M 0s
# 440750K .......... .......... .......... .......... .......... 97%  172M 0s
# 440800K .......... .......... .......... .......... .......... 97%  154M 0s
# 440850K .......... .......... .......... .......... .......... 97% 65.7M 0s
# 440900K .......... .......... .......... .......... .......... 97%  195M 0s
# 440950K .......... .......... .......... .......... .......... 97%  165M 0s
# 441000K .......... .......... .......... .......... .......... 97%  166M 0s
# 441050K .......... .......... .......... .......... .......... 97% 53.8M 0s
# 441100K .......... .......... .......... .......... .......... 97%  105M 0s
# 441150K .......... .......... .......... .......... .......... 97%  182M 0s
# 441200K .......... .......... .......... .......... .......... 97%  160M 0s
# 441250K .......... .......... .......... .......... .......... 97%  153M 0s
# 441300K .......... .......... .......... .......... .......... 97%  154M 0s
# 441350K .......... .......... .......... .......... .......... 98%  132M 0s
# 441400K .......... .......... .......... .......... .......... 98%  126M 0s
# 441450K .......... .......... .......... .......... .......... 98%  194M 0s
# 441500K .......... .......... .......... .......... .......... 98% 84.9M 0s
# 441550K .......... .......... .......... .......... .......... 98%  173M 0s
# 441600K .......... .......... .......... .......... .......... 98%  173M 0s
# 441650K .......... .......... .......... .......... .......... 98%  171M 0s
# 441700K .......... .......... .......... .......... .......... 98%  211M 0s
# 441750K .......... .......... .......... .......... .......... 98%  205M 0s
# 441800K .......... .......... .......... .......... .......... 98%  131M 0s
# 441850K .......... .......... .......... .......... .......... 98% 76.9M 0s
# 441900K .......... .......... .......... .......... .......... 98%  156M 0s
# 441950K .......... .......... .......... .......... .......... 98%  172M 0s
# 442000K .......... .......... .......... .......... .......... 98%  121M 0s
# 442050K .......... .......... .......... .......... .......... 98%  150M 0s
# 442100K .......... .......... .......... .......... .......... 98%  175M 0s
# 442150K .......... .......... .......... .......... .......... 98%  207M 0s
# 442200K .......... .......... .......... .......... .......... 98%  177M 0s
# 442250K .......... .......... .......... .......... .......... 98%  172M 0s
# 442300K .......... .......... .......... .......... .......... 98%  134M 0s
# 442350K .......... .......... .......... .......... .......... 98%  117M 0s
# 442400K .......... .......... .......... .......... .......... 98%  125M 0s
# 442450K .......... .......... .......... .......... .......... 98%  203M 0s
# 442500K .......... .......... .......... .......... .......... 98%  184M 0s
# 442550K .......... .......... .......... .......... .......... 98%  108M 0s
# 442600K .......... .......... .......... .......... .......... 98%  150M 0s
# 442650K .......... .......... .......... .......... .......... 98%  202M 0s
# 442700K .......... .......... .......... .......... .......... 98%  199M 0s
# 442750K .......... .......... .......... .......... .......... 98% 87.7M 0s
# 442800K .......... .......... .......... .......... .......... 98%  127M 0s
# 442850K .......... .......... .......... .......... .......... 98%  179M 0s
# 442900K .......... .......... .......... .......... .......... 98%  211M 0s
# 442950K .......... .......... .......... .......... .......... 98%  210M 0s
# 443000K .......... .......... .......... .......... .......... 98%  154M 0s
# 443050K .......... .......... .......... .......... .......... 98%  114M 0s
# 443100K .......... .......... .......... .......... .......... 98%  148M 0s
# 443150K .......... .......... .......... .......... .......... 98%  195M 0s
# 443200K .......... .......... .......... .......... .......... 98%  172M 0s
# 443250K .......... .......... .......... .......... .......... 98%  186M 0s
# 443300K .......... .......... .......... .......... .......... 98%  205M 0s
# 443350K .......... .......... .......... .......... .......... 98%  128M 0s
# 443400K .......... .......... .......... .......... .......... 98%  168M 0s
# 443450K .......... .......... .......... .......... .......... 98%  205M 0s
# 443500K .......... .......... .......... .......... .......... 98%  144M 0s
# 443550K .......... .......... .......... .......... .......... 98% 92.3M 0s
# 443600K .......... .......... .......... .......... .......... 98%  160M 0s
# 443650K .......... .......... .......... .......... .......... 98%  181M 0s
# 443700K .......... .......... .......... .......... .......... 98%  201M 0s
# 443750K .......... .......... .......... .......... .......... 98%  180M 0s
# 443800K .......... .......... .......... .......... .......... 98%  129M 0s
# 443850K .......... .......... .......... .......... .......... 98%  113M 0s
# 443900K .......... .......... .......... .......... .......... 98%  164M 0s
# 443950K .......... .......... .......... .......... .......... 98%  192M 0s
# 444000K .......... .......... .......... .......... .......... 98%  149M 0s
# 444050K .......... .......... .......... .......... .......... 98%  150M 0s
# 444100K .......... .......... .......... .......... .......... 98%  140M 0s
# 444150K .......... .......... .......... .......... .......... 98%  193M 0s
# 444200K .......... .......... .......... .......... .......... 98%  174M 0s
# 444250K .......... .......... .......... .......... .......... 98%  174M 0s
# 444300K .......... .......... .......... .......... .......... 98% 58.5M 0s
# 444350K .......... .......... .......... .......... .......... 98%  202M 0s
# 444400K .......... .......... .......... .......... .......... 98%  166M 0s
# 444450K .......... .......... .......... .......... .......... 98%  216M 0s
# 444500K .......... .......... .......... .......... .......... 98%  193M 0s
# 444550K .......... .......... .......... .......... .......... 98%  133M 0s
# 444600K .......... .......... .......... .......... .......... 98%  123M 0s
# 444650K .......... .......... .......... .......... .......... 98%  196M 0s
# 444700K .......... .......... .......... .......... .......... 98%  191M 0s
# 444750K .......... .......... .......... .......... .......... 98%  156M 0s
# 444800K .......... .......... .......... .......... .......... 98%  106M 0s
# 444850K .......... .......... .......... .......... .......... 98%  135M 0s
# 444900K .......... .......... .......... .......... .......... 98%  155M 0s
# 444950K .......... .......... .......... .......... .......... 98%  203M 0s
# 445000K .......... .......... .......... .......... .......... 98%  162M 0s
# 445050K .......... .......... .......... .......... .......... 98%  136M 0s
# 445100K .......... .......... .......... .......... .......... 98%  207M 0s
# 445150K .......... .......... .......... .......... .......... 98%  205M 0s
# 445200K .......... .......... .......... .......... .......... 98%  169M 0s
# 445250K .......... .......... .......... .......... .......... 98%  161M 0s
# 445300K .......... .......... .......... .......... .......... 98% 60.9M 0s
# 445350K .......... .......... .......... .......... .......... 98%  205M 0s
# 445400K .......... .......... .......... .......... .......... 98%  173M 0s
# 445450K .......... .......... .......... .......... .......... 98%  218M 0s
# 445500K .......... .......... .......... .......... .......... 98%  150M 0s
# 445550K .......... .......... .......... .......... .......... 98%  188M 0s
# 445600K .......... .......... .......... .......... .......... 98%  165M 0s
# 445650K .......... .......... .......... .......... .......... 98%  195M 0s
# 445700K .......... .......... .......... .......... .......... 98%  192M 0s
# 445750K .......... .......... .......... .......... .......... 98%  198M 0s
# 445800K .......... .......... .......... .......... .......... 98%  170M 0s
# 445850K .......... .......... .......... .......... .......... 98%  197M 0s
# 445900K .......... .......... .......... .......... .......... 99%  176M 0s
# 445950K .......... .......... .......... .......... .......... 99%  193M 0s
# 446000K .......... .......... .......... .......... .......... 99%  170M 0s
# 446050K .......... .......... .......... .......... .......... 99%  139M 0s
# 446100K .......... .......... .......... .......... .......... 99%  192M 0s
# 446150K .......... .......... .......... .......... .......... 99%  200M 0s
# 446200K .......... .......... .......... .......... .......... 99%  161M 0s
# 446250K .......... .......... .......... .......... .......... 99%  130M 0s
# 446300K .......... .......... .......... .......... .......... 99%  193M 0s
# 446350K .......... .......... .......... .......... .......... 99%  209M 0s
# 446400K .......... .......... .......... .......... .......... 99%  147M 0s
# 446450K .......... .......... .......... .......... .......... 99%  200M 0s
# 446500K .......... .......... .......... .......... .......... 99%  216M 0s
# 446550K .......... .......... .......... .......... .......... 99%  194M 0s
# 446600K .......... .......... .......... .......... .......... 99%  153M 0s
# 446650K .......... .......... .......... .......... .......... 99%  201M 0s
# 446700K .......... .......... .......... .......... .......... 99%  209M 0s
# 446750K .......... .......... .......... .......... .......... 99%  195M 0s
# 446800K .......... .......... .......... .......... .......... 99%  162M 0s
# 446850K .......... .......... .......... .......... .......... 99%  208M 0s
# 446900K .......... .......... .......... .......... .......... 99%  166M 0s
# 446950K .......... .......... .......... .......... .......... 99%  181M 0s
# 447000K .......... .......... .......... .......... .......... 99%  156M 0s
# 447050K .......... .......... .......... .......... .......... 99%  156M 0s
# 447100K .......... .......... .......... .......... .......... 99%  176M 0s
# 447150K .......... .......... .......... .......... .......... 99%  188M 0s
# 447200K .......... .......... .......... .......... .......... 99%  173M 0s
# 447250K .......... .......... .......... .......... .......... 99%  139M 0s
# 447300K .......... .......... .......... .......... .......... 99%  163M 0s
# 447350K .......... .......... .......... .......... .......... 99%  180M 0s
# 447400K .......... .......... .......... .......... .......... 99%  159M 0s
# 447450K .......... .......... .......... .......... .......... 99%  182M 0s
# 447500K .......... .......... .......... .......... .......... 99%  177M 0s
# 447550K .......... .......... .......... .......... .......... 99%  197M 0s
# 447600K .......... .......... .......... .......... .......... 99%  173M 0s
# 447650K .......... .......... .......... .......... .......... 99%  161M 0s
# 447700K .......... .......... .......... .......... .......... 99%  203M 0s
# 447750K .......... .......... .......... .......... .......... 99%  221M 0s
# 447800K .......... .......... .......... .......... .......... 99%  154M 0s
# 447850K .......... .......... .......... .......... .......... 99%  158M 0s
# 447900K .......... .......... .......... .......... .......... 99%  180M 0s
# 447950K .......... .......... .......... .......... .......... 99%  170M 0s
# 448000K .......... .......... .......... .......... .......... 99%  145M 0s
# 448050K .......... .......... .......... .......... .......... 99%  188M 0s
# 448100K .......... .......... .......... .......... .......... 99%  177M 0s
# 448150K .......... .......... .......... .......... .......... 99%  203M 0s
# 448200K .......... .......... .......... .......... .......... 99%  159M 0s
# 448250K .......... .......... .......... .......... .......... 99%  142M 0s
# 448300K .......... .......... .......... .......... .......... 99%  156M 0s
# 448350K .......... .......... .......... .......... .......... 99%  156M 0s
# 448400K .......... .......... .......... .......... .......... 99%  156M 0s
# 448450K .......... .......... .......... .......... .......... 99%  183M 0s
# 448500K .......... .......... .......... .......... .......... 99%  178M 0s
# 448550K .......... .......... .......... .......... .......... 99%  175M 0s
# 448600K .......... .......... .......... .......... .......... 99%  150M 0s
# 448650K .......... .......... .......... .......... .......... 99%  208M 0s
# 448700K .......... .......... .......... .......... .......... 99%  124M 0s
# 448750K .......... .......... .......... .......... .......... 99%  194M 0s
# 448800K .......... .......... .......... .......... .......... 99%  156M 0s
# 448850K .......... .......... .......... .......... .......... 99%  164M 0s
# 448900K .......... .......... .......... .......... .......... 99%  195M 0s
# 448950K .......... .......... .......... .......... .......... 99%  216M 0s
# 449000K .......... .......... .......... .......... .......... 99%  175M 0s
# 449050K .......... .......... .......... .......... .......... 99%  187M 0s
# 449100K .......... .......... .......... .......... .......... 99%  197M 0s
# 449150K .......... .......... .......... .......... .......... 99%  206M 0s
# 449200K .......... .......... .......... .......... .......... 99%  182M 0s
# 449250K .......... .......... .......... .......... .......... 99%  189M 0s
# 449300K .......... .......... .......... .......... .......... 99%  205M 0s
# 449350K .......... .......... .......... .......... .......... 99%  205M 0s
# 449400K .......... .......... .......... .......... .......... 99%  178M 0s
# 449450K .......... .......... .......... .......... .......... 99%  189M 0s
# 449500K .......... .......... .......... .......... .......... 99%  157M 0s
# 449550K .......... .......... .......... .......... .......... 99%  202M 0s
# 449600K .......... .......... .......... .......... .......... 99%  167M 0s
# 449650K .......... .......... .......... .......... .......... 99% 61.5M 0s
# 449700K .......... .......... .......... .......... .......... 99%  168M 0s
# 449750K .......... .......... .......... .......... .......... 99%  185M 0s
# 449800K .......... .......... .......... .......... .......... 99%  163M 0s
# 449850K .......... .......... .......... .......... .......... 99%  182M 0s
# 449900K .......... .......... .......... .......... .......... 99%  174M 0s
# 449950K .......... .......... .......... .......... .......... 99%  188M 0s
# 450000K .......... .......... .......... .......... .......... 99%  161M 0s
# 450050K .......... .......... .......... .......... .......... 99%  179M 0s
# 450100K .......... .......... .......... .......... .......... 99%  174M 0s
# 450150K .......... .......... .......... .......... .......... 99%  181M 0s
# 450200K .......... .......... .......... .......... .......... 99%  161M 0s
# 450250K .......... .......... .......... .......... .......... 99%  189M 0s
# 450300K .......... .......... .......... .......... .......... 99%  212M 0s
# 450350K .......... .......... .......... .......... .......... 99%  209M 0s
# 450400K .......                                               100%  144M=3.5s
#
# 2022-05-16 07:30:27 (126 MB/s) - ‘R50+ViT-B_16.npz’ saved [461217452/461217452]

# %%
# !git clone https://github.com/Beckschen/TransUNet.git
# Out:
# Cloning into 'TransUNet'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 92 (delta 31), reused 27 (delta 27), pack-reused 50
# Unpacking objects: 100% (92/92), done.

# %%
 # %%bash
 cd TransUNet
 ls -p
# Out:
# datasets/
# LICENSE
# lists/
# networks/
# README.md
# requirements.txt
# test.py
# trainer.py
# train.py
# utils.py

# %%
 # %%bash
 cd TransUNet
 pip install -r requirements.txt
# Out:
# Collecting torch==1.4.0
#   Downloading torch-1.4.0-cp37-cp37m-manylinux1_x86_64.whl (753.4 MB)
# Collecting torchvision==0.5.0
#   Downloading torchvision-0.5.0-cp37-cp37m-manylinux1_x86_64.whl (4.0 MB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (4.64.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (2.8.0)
# Collecting tensorboardX
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
# Collecting ml-collections
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
# Collecting medpy
#   Downloading MedPy-0.4.0.tar.gz (151 kB)
# Collecting SimpleITK
#   Downloading SimpleITK-2.1.1.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (48.4 MB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0->-r requirements.txt (line 2)) (7.1.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (3.3.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.44.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (0.37.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (3.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->-r requirements.txt (line 5)) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r requirements.txt (line 5)) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 5)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 5)) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 5)) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from ml-collections->-r requirements.txt (line 7)) (3.13)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from ml-collections->-r requirements.txt (line 7)) (0.5.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->-r requirements.txt (line 11)) (1.5.2)
# Building wheels for collected packages: ml-collections, medpy
#   Building wheel for ml-collections (setup.py): started
#   Building wheel for ml-collections (setup.py): finished with status 'done'
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94524 sha256=27ddd3309cfa2d29e54c83c62097f8ea9ee1d9dadb6dfe921568254dfb46a9cc
#   Stored in directory: /root/.cache/pip/wheels/b7/da/64/33c926a1b10ff19791081b705879561b715a8341a856a3bbd2
#   Building wheel for medpy (setup.py): started
#   Building wheel for medpy (setup.py): finished with status 'done'
#   Created wheel for medpy: filename=MedPy-0.4.0-cp37-cp37m-linux_x86_64.whl size=754467 sha256=1cc060c5232a79ba9e3335f47298308440e93e2ba693c44134b9c9f91b08acbf
#   Stored in directory: /root/.cache/pip/wheels/b0/57/3a/da1183f22a6afb42e11138daa6a759de233fd977a984333602
# Successfully built ml-collections medpy
# Installing collected packages: torch, SimpleITK, torchvision, tensorboardX, ml-collections, medpy
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
# Successfully installed SimpleITK-2.1.1.2 medpy-0.4.0 ml-collections-0.1.1 tensorboardX-2.5 torch-1.4.0 torchvision-0.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.4.0 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.4.0 which is incompatible.

# %%
 # %%bash
 cd TransUNet/
 CUDA_VISIBLE_DEVICES=0 python train.py --dataset Synapse --vit_name R50-ViT-B_16
# Out:
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=50 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "train.py", line 89, in <module>
#     net = ViT_seg(config_vit, img_size=args.img_size, num_classes=config_vit.n_classes).cuda()
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 304, in cuda
#     return self._apply(lambda t: t.cuda(device))
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 201, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 201, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 201, in _apply
#     module._apply(fn)
#   [Previous line repeated 2 more times]
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 223, in _apply
#     param_applied = fn(param)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 304, in <lambda>
#     return self._apply(lambda t: t.cuda(device))
#   File "/usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py", line 197, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:50

# %%
# %%bash
#  cd TransUNet/
#  python test.py --dataset Synapse --vit_name R50-ViT-B_16
# Out:
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=50 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "test.py", line 118, in <module>
#     net = ViT_seg(config_vit, img_size=args.img_size, num_classes=config_vit.n_classes).cuda()
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 304, in cuda
#     return self._apply(lambda t: t.cuda(device))
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 201, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 201, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 201, in _apply
#     module._apply(fn)
#   [Previous line repeated 2 more times]
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 223, in _apply
#     param_applied = fn(param)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 304, in <lambda>
#     return self._apply(lambda t: t.cuda(device))
#   File "/usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py", line 197, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:50

# %%
 # %%bash
 sudo apt-get install tree
 tree
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (328 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# .
# ├── model
# │   └── TU_Synapse224
# │       └── TU_pretrain_R50-ViT-B_16_skip3_epo150_bs24_224
# ├── sample_data
# │   ├── anscombe.json
# │   ├── california_housing_test.csv
# │   ├── california_housing_train.csv
# │   ├── mnist_test.csv
# │   ├── mnist_train_small.csv
# │   └── README.md
# └── TransUNet
#     ├── datasets
#     │   ├── dataset_synapse.py
#     │   ├── __pycache__
#     │   │   └── dataset_synapse.cpython-37.pyc
#     │   └── README.md
#     ├── LICENSE
#     ├── lists
#     │   └── lists_Synapse
#     │       ├── all.lst
#     │       ├── test_vol.txt
#     │       └── train.txt
#     ├── networks
#     │   ├── __pycache__
#     │   │   ├── vit_seg_configs.cpython-37.pyc
#     │   │   ├── vit_seg_modeling.cpython-37.pyc
#     │   │   └── vit_seg_modeling_resnet_skip.cpython-37.pyc
#     │   ├── vit_seg_configs.py
#     │   ├── vit_seg_modeling.py
#     │   └── vit_seg_modeling_resnet_skip.py
#     ├── __pycache__
#     │   ├── trainer.cpython-37.pyc
#     │   └── utils.cpython-37.pyc
#     ├── README.md
#     ├── requirements.txt
#     ├── test.py
#     ├── trainer.py
#     ├── train.py
#     └── utils.py
#
# 12 directories, 27 files
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id': '14gAvu8tgEq767-bbYDoQjH9GB'})
download.GetContentFile('train_npz')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in FetchMetadata(self, fields, fetch_all)
#     236                                                  fields=fields)\
# --> 237           .execute(http=self.http)
#     238       except errors.HttpError as error:
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     914         if resp.status >= 300:
# --> 915             raise HttpError(resp, content, uri=self.uri)
#     916         return self.postproc(resp, content)
#
# HttpError: <HttpError 404 when requesting https://www.googleapis.com/drive/v2/files/14gAvu8tgEq767-bbYDoQjH9GB?alt=json returned "File not found: 14gAvu8tgEq767-bbYDoQjH9GB". Details: "File not found: 14gAvu8tgEq767-bbYDoQjH9GB">
#
# During handling of the above exception, another exception occurred:
#
# ApiRequestError                           Traceback (most recent call last)
# <ipython-input-6-a5d8b0da2b36> in <module>()
#       1 download = drive.CreateFile({'id': '14gAvu8tgEq767-bbYDoQjH9GB'})
# ----> 2 download.GetContentFile('train_npz')
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in GetContentFile(self, filename, mimetype, remove_bom)
#     208                     type(self.content) is not io.BytesIO or \
#     209                     self.has_bom == remove_bom:
# --> 210       self.FetchContent(mimetype, remove_bom)
#     211     f = open(filename, 'wb')
#     212     f.write(self.content.getvalue())
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in _decorated(self, *args, **kwargs)
#      40   def _decorated(self, *args, **kwargs):
#      41     if not self.uploaded:
# ---> 42       self.FetchMetadata()
#      43     return decoratee(self, *args, **kwargs)
#      44   return _decorated
#
# /usr/local/lib/python3.7/dist-packages/pydrive/auth.py in _decorated(self, *args, **kwargs)
#      73       self.http = self.auth.Get_Http_Object()
#      74
# ---> 75     return decoratee(self, *args, **kwargs)
#      76   return _decorated
#      77
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in FetchMetadata(self, fields, fetch_all)
#     237           .execute(http=self.http)
#     238       except errors.HttpError as error:
# --> 239         raise ApiRequestError(error)
#     240       else:
#     241         self.uploaded = True
#
# ApiRequestError: <HttpError 404 when requesting https://www.googleapis.com/drive/v2/files/14gAvu8tgEq767-bbYDoQjH9GB?alt=json returned "File not found: 14gAvu8tgEq767-bbYDoQjH9GB". Details: "File not found: 14gAvu8tgEq767-bbYDoQjH9GB">

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import random
import h5py
import numpy as np
import torch
from scipy import ndimage
from scipy.ndimage.interpolation import zoom
from torch.utils.data import Dataset


def random_rot_flip(image, label):
    k = np.random.randint(0, 4)
    image = np.rot90(image, k)
    label = np.rot90(label, k)
    axis = np.random.randint(0, 2)
    image = np.flip(image, axis=axis).copy()
    label = np.flip(label, axis=axis).copy()
    return image, label


def random_rotate(image, label):
    angle = np.random.randint(-20, 20)
    image = ndimage.rotate(image, angle, order=0, reshape=False)
    label = ndimage.rotate(label, angle, order=0, reshape=False)
    return image, label


class RandomGenerator(object):
    def __init__(self, output_size):
        self.output_size = output_size

    def __call__(self, sample):
        image, label = sample['image'], sample['label']

        if random.random() > 0.5:
            image, label = random_rot_flip(image, label)
        elif random.random() > 0.5:
            image, label = random_rotate(image, label)
        x, y = image.shape
        if x != self.output_size[0] or y != self.output_size[1]:
            image = zoom(image, (self.output_size[0] / x, self.output_size[1] / y), order=3)  # why not 3?
            label = zoom(label, (self.output_size[0] / x, self.output_size[1] / y), order=0)
        image = torch.from_numpy(image.astype(np.float32)).unsqueeze(0)
        label = torch.from_numpy(label.astype(np.float32))
        sample = {'image': image, 'label': label.long()}
        return sample


class Synapse_dataset(Dataset):
    def __init__(self, base_dir, list_dir, split, transform=None):
        self.transform = transform  # using transform in torch!
        self.split = split
        self.sample_list = open(os.path.join(list_dir, self.split+'.txt')).readlines()
        self.data_dir = base_dir

    def __len__(self):
        return len(self.sample_list)

    def __getitem__(self, idx):
        if self.split == "train":
            slice_name = self.sample_list[idx].strip('\n')
            data_path = os.path.join(self.data_dir, slice_name+'.npz')
            data = np.load(data_path)
            image, label = data['image'], data['label']
        else:
            vol_name = self.sample_list[idx].strip('\n')
            filepath = self.data_dir + "/{}.npy.h5".format(vol_name)
            data = h5py.File(filepath)
            image, label = data['image'][:], data['label'][:]

        sample = {'image': image, 'label': label}
        if self.transform:
            sample = self.transform(sample)
        sample['case_name'] = self.sample_list[idx].strip('\n')
        return sample

# %%
from os.path import join
from os.path import normpath
import platform

def pjoin(path, *paths):
    p = join(path, *paths)
    if platform.system() == "Windows":
        return normpath(p).replace('\\','/')
    else:
        return p

# %%
pip install ml-collections
# Out:
# Collecting ml-collections
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 3.6 MB/s
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from ml-collections) (1.0.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from ml-collections) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from ml-collections) (1.15.0)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from ml-collections) (0.5.5)
# Building wheels for collected packages: ml-collections
#   Building wheel for ml-collections (setup.py) ... done
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94524 sha256=6e7bb9ebb0bdae308c69bd84fd9231776c953946331984d099d01ad757ff4390
#   Stored in directory: /root/.cache/pip/wheels/b7/da/64/33c926a1b10ff19791081b705879561b715a8341a856a3bbd2
# Successfully built ml-collections
# Installing collected packages: ml-collections
# Successfully installed ml-collections-0.1.1

# %%
pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 6.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5

# %%
pip install MedPy
# Out:
# Collecting MedPy
#   Downloading MedPy-0.4.0.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 3.7 MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from MedPy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from MedPy) (1.21.6)
# Collecting SimpleITK>=1.1.0
#   Downloading SimpleITK-2.1.1.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (48.4 MB)
#      |████████████████████████████████| 48.4 MB 32 kB/s
# Building wheels for collected packages: MedPy
#   Building wheel for MedPy (setup.py) ... done
#   Created wheel for MedPy: filename=MedPy-0.4.0-cp37-cp37m-linux_x86_64.whl size=754435 sha256=172b28947e9305b6b98ec5ba254bf16521238efa949d0121c07038cb5728378c
#   Stored in directory: /root/.cache/pip/wheels/b0/57/3a/da1183f22a6afb42e11138daa6a759de233fd977a984333602
# Successfully built MedPy
# Installing collected packages: SimpleITK, MedPy
# Successfully installed MedPy-0.4.0 SimpleITK-2.1.1.2

# %%
import ml_collections

def get_b16_config():
    """Returns the ViT-B/16 configuration."""
    config = ml_collections.ConfigDict()
    config.patches = ml_collections.ConfigDict({'size': (16, 16)})
    config.hidden_size = 768
    config.transformer = ml_collections.ConfigDict()
    config.transformer.mlp_dim = 3072
    config.transformer.num_heads = 12
    config.transformer.num_layers = 12
    config.transformer.attention_dropout_rate = 0.0
    config.transformer.dropout_rate = 0.1

    config.classifier = 'seg'
    config.representation_size = None
    config.resnet_pretrained_path = None
    config.pretrained_path = '/content/gdrive/MyDrive/Research dataset/data/Synapse/imagenet21k+imagenet2012_ViT-B_16.npz'
    config.patch_size = 16

    config.decoder_channels = (256, 128, 64, 16)
    config.n_classes = 2
    config.activation = 'softmax'
    return config


def get_testing():
    """Returns a minimal configuration for testing."""
    config = ml_collections.ConfigDict()
    config.patches = ml_collections.ConfigDict({'size': (16, 16)})
    config.hidden_size = 1
    config.transformer = ml_collections.ConfigDict()
    config.transformer.mlp_dim = 1
    config.transformer.num_heads = 1
    config.transformer.num_layers = 1
    config.transformer.attention_dropout_rate = 0.0
    config.transformer.dropout_rate = 0.1
    config.classifier = 'token'
    config.representation_size = None
    return config

def get_r50_b16_config():
    """Returns the Resnet50 + ViT-B/16 configuration."""
    config = get_b16_config()
    config.patches.grid = (8, 8)
    config.resnet = ml_collections.ConfigDict()
    config.resnet.num_layers = (3, 4, 9)
    config.resnet.width_factor = 1

    config.classifier = 'seg'
    config.pretrained_path = '/content/gdrive/MyDrive/Research dataset/data/Synapse/imagenet21k+imagenet2012_R50+ViT-B_16.npz'
    config.decoder_channels = (256, 128, 64, 16)
    config.skip_channels = [512, 256, 64, 16]
    config.n_classes = 2
    config.n_skip = 3
    config.activation = 'softmax'

    return config


def get_b32_config():
    """Returns the ViT-B/32 configuration."""
    config = get_b16_config()
    config.patches.size = (32, 32)
    config.pretrained_path = '../model/vit_checkpoint/imagenet21k/ViT-B_32.npz'
    return config


def get_l16_config():
    """Returns the ViT-L/16 configuration."""
    config = ml_collections.ConfigDict()
    config.patches = ml_collections.ConfigDict({'size': (16, 16)})
    config.hidden_size = 1024
    config.transformer = ml_collections.ConfigDict()
    config.transformer.mlp_dim = 4096
    config.transformer.num_heads = 16
    config.transformer.num_layers = 24
    config.transformer.attention_dropout_rate = 0.0
    config.transformer.dropout_rate = 0.1
    config.representation_size = None

    # custom
    config.classifier = 'seg'
    config.resnet_pretrained_path = None
    config.pretrained_path = '../model/vit_checkpoint/imagenet21k/ViT-L_16.npz'
    config.decoder_channels = (256, 128, 64, 16)
    config.n_classes = 2
    config.activation = 'softmax'
    return config





def get_l32_config():
    """Returns the ViT-L/32 configuration."""
    config = get_l16_config()
    config.patches.size = (32, 32)
    return config


def get_h14_config():
    """Returns the ViT-L/16 configuration."""
    config = ml_collections.ConfigDict()
    config.patches = ml_collections.ConfigDict({'size': (14, 14)})
    config.hidden_size = 1280
    config.transformer = ml_collections.ConfigDict()
    config.transformer.mlp_dim = 5120
    config.transformer.num_heads = 16
    config.transformer.num_layers = 32
    config.transformer.attention_dropout_rate = 0.0
    config.transformer.dropout_rate = 0.1
    config.classifier = 'token'
    config.representation_size = None

    return config

# %%
import math

from collections import OrderedDict

import torch
import torch.nn as nn
import torch.nn.functional as F
from os.path import join
from os.path import normpath
import platform

def pjoin(path, *paths):
    p = join(path, *paths)
    if platform.system() == "Windows":
        return normpath(p).replace('\\','/')
    else:
        return p

def np2th(weights, conv=False):
    """Possibly convert HWIO to OIHW."""
    if conv:
        weights = weights.transpose([3, 2, 0, 1])
    return torch.from_numpy(weights)


class StdConv2d(nn.Conv2d):

    def forward(self, x):
        w = self.weight
        v, m = torch.var_mean(w, dim=[1, 2, 3], keepdim=True, unbiased=False)
        w = (w - m) / torch.sqrt(v + 1e-5)
        return F.conv2d(x, w, self.bias, self.stride, self.padding,
                        self.dilation, self.groups)


def conv3x3(cin, cout, stride=1, groups=1, bias=False):
    return StdConv2d(cin, cout, kernel_size=3, stride=stride,
                     padding=1, bias=bias, groups=groups)


def conv1x1(cin, cout, stride=1, bias=False):
    return StdConv2d(cin, cout, kernel_size=1, stride=stride,
                     padding=0, bias=bias)


class PreActBottleneck(nn.Module):
    """Pre-activation (v2) bottleneck block.
    """

    def __init__(self, cin, cout=None, cmid=None, stride=1):
        super().__init__()
        cout = cout or cin
        cmid = cmid or cout//4

        self.gn1 = nn.GroupNorm(32, cmid, eps=1e-6)
        self.conv1 = conv1x1(cin, cmid, bias=False)
        self.gn2 = nn.GroupNorm(32, cmid, eps=1e-6)
        self.conv2 = conv3x3(cmid, cmid, stride, bias=False)  # Original code has it on conv1!!
        self.gn3 = nn.GroupNorm(32, cout, eps=1e-6)
        self.conv3 = conv1x1(cmid, cout, bias=False)
        self.relu = nn.ReLU(inplace=True)

        if (stride != 1 or cin != cout):
            # Projection also with pre-activation according to paper.
            self.downsample = conv1x1(cin, cout, stride, bias=False)
            self.gn_proj = nn.GroupNorm(cout, cout)

    def forward(self, x):

        # Residual branch
        residual = x
        if hasattr(self, 'downsample'):
            residual = self.downsample(x)
            residual = self.gn_proj(residual)

        # Unit's branch
        y = self.relu(self.gn1(self.conv1(x)))
        y = self.relu(self.gn2(self.conv2(y)))
        y = self.gn3(self.conv3(y))

        y = self.relu(residual + y)
        return y

    def load_from(self, weights, n_block, n_unit):
        conv1_weight = np2th(weights[pjoin(n_block, n_unit, "conv1/kernel")], conv=True)
        conv2_weight = np2th(weights[pjoin(n_block, n_unit, "conv2/kernel")], conv=True)
        conv3_weight = np2th(weights[pjoin(n_block, n_unit, "conv3/kernel")], conv=True)

        gn1_weight = np2th(weights[pjoin(n_block, n_unit, "gn1/scale")])
        gn1_bias = np2th(weights[pjoin(n_block, n_unit, "gn1/bias")])

        gn2_weight = np2th(weights[pjoin(n_block, n_unit, "gn2/scale")])
        gn2_bias = np2th(weights[pjoin(n_block, n_unit, "gn2/bias")])

        gn3_weight = np2th(weights[pjoin(n_block, n_unit, "gn3/scale")])
        gn3_bias = np2th(weights[pjoin(n_block, n_unit, "gn3/bias")])

        self.conv1.weight.copy_(conv1_weight)
        self.conv2.weight.copy_(conv2_weight)
        self.conv3.weight.copy_(conv3_weight)

        self.gn1.weight.copy_(gn1_weight.view(-1))
        self.gn1.bias.copy_(gn1_bias.view(-1))

        self.gn2.weight.copy_(gn2_weight.view(-1))
        self.gn2.bias.copy_(gn2_bias.view(-1))

        self.gn3.weight.copy_(gn3_weight.view(-1))
        self.gn3.bias.copy_(gn3_bias.view(-1))

        if hasattr(self, 'downsample'):
            proj_conv_weight = np2th(weights[pjoin(n_block, n_unit, "conv_proj/kernel")], conv=True)
            proj_gn_weight = np2th(weights[pjoin(n_block, n_unit, "gn_proj/scale")])
            proj_gn_bias = np2th(weights[pjoin(n_block, n_unit, "gn_proj/bias")])

            self.downsample.weight.copy_(proj_conv_weight)
            self.gn_proj.weight.copy_(proj_gn_weight.view(-1))
            self.gn_proj.bias.copy_(proj_gn_bias.view(-1))

class ResNetV2(nn.Module):
    """Implementation of Pre-activation (v2) ResNet mode."""

    def __init__(self, block_units, width_factor):
        super().__init__()
        width = int(64 * width_factor)
        self.width = width

        self.root = nn.Sequential(OrderedDict([
            ('conv', StdConv2d(3, width, kernel_size=7, stride=2, bias=False, padding=3)),
            ('gn', nn.GroupNorm(32, width, eps=1e-6)),
            ('relu', nn.ReLU(inplace=True)),
            # ('pool', nn.MaxPool2d(kernel_size=3, stride=2, padding=0))
        ]))

        self.body = nn.Sequential(OrderedDict([
            ('block1/', nn.Sequential(OrderedDict(
                [('unit1/', PreActBottleneck(cin=width, cout=width*4, cmid=width))] +
                [(f'unit{i:d}/', PreActBottleneck(cin=width*4, cout=width*4, cmid=width)) for i in range(2, block_units[0] + 1)],
                ))),
            ('block2/', nn.Sequential(OrderedDict(
                [('unit1/', PreActBottleneck(cin=width*4, cout=width*8, cmid=width*2, stride=2))] +
                [(f'unit{i:d}/', PreActBottleneck(cin=width*8, cout=width*8, cmid=width*2)) for i in range(2, block_units[1] + 1)],
                ))),
            ('block3/', nn.Sequential(OrderedDict(
                [('unit1/', PreActBottleneck(cin=width*8, cout=width*16, cmid=width*4, stride=2))] +
                [(f'unit{i:d}/', PreActBottleneck(cin=width*16, cout=width*16, cmid=width*4)) for i in range(2, block_units[2] + 1)],
                ))),
        ]))

    def forward(self, x):
        features = []
        b, c, in_size, _ = x.size()
        x = self.root(x)
        features.append(x)
        x = nn.MaxPool2d(kernel_size=3, stride=2, padding=0)(x)
        for i in range(len(self.body)-1):
            x = self.body[i](x)
            right_size = int(in_size / 4 / (i+1))
            if x.size()[2] != right_size:
                pad = right_size - x.size()[2]
                assert pad < 3 and pad > 0, "x {} should {}".format(x.size(), right_size)
                feat = torch.zeros((b, x.size()[1], right_size, right_size), device=x.device)
                feat[:, :, 0:x.size()[2], 0:x.size()[3]] = x[:]
            else:
                feat = x
            features.append(feat)
        x = self.body[-1](x)
        return x, features[::-1]

# %%
# coding=utf-8
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import copy
import logging
import math


import torch
import torch.nn as nn
import numpy as np

from torch.nn import CrossEntropyLoss, Dropout, Softmax, Linear, Conv2d, LayerNorm
from torch.nn.modules.utils import _pair
from scipy import ndimage



logger = logging.getLogger(__name__)


ATTENTION_Q = "MultiHeadDotProductAttention_1/query/"
ATTENTION_K = "MultiHeadDotProductAttention_1/key/"
ATTENTION_V = "MultiHeadDotProductAttention_1/value/"
ATTENTION_OUT = "MultiHeadDotProductAttention_1/out/"
FC_0 = "MlpBlock_3/Dense_0/"
FC_1 = "MlpBlock_3/Dense_1/"
ATTENTION_NORM = "LayerNorm_0/"
MLP_NORM = "LayerNorm_2/"


def np2th(weights, conv=False):
    """Possibly convert HWIO to OIHW."""
    if conv:
        weights = weights.transpose([3, 2, 0, 1])
    return torch.from_numpy(weights)


def swish(x):
    return x * torch.sigmoid(x)


ACT2FN = {"gelu": torch.nn.functional.gelu, "relu": torch.nn.functional.relu, "swish": swish}


class Attention(nn.Module):
    def __init__(self, config, vis):
        super(Attention, self).__init__()
        self.vis = vis
        self.num_attention_heads = config.transformer["num_heads"]
        self.attention_head_size = int(config.hidden_size / self.num_attention_heads)
        self.all_head_size = self.num_attention_heads * self.attention_head_size

        self.query = Linear(config.hidden_size, self.all_head_size)
        self.key = Linear(config.hidden_size, self.all_head_size)
        self.value = Linear(config.hidden_size, self.all_head_size)

        self.out = Linear(config.hidden_size, config.hidden_size)
        self.attn_dropout = Dropout(config.transformer["attention_dropout_rate"])
        self.proj_dropout = Dropout(config.transformer["attention_dropout_rate"])

        self.softmax = Softmax(dim=-1)

    def transpose_for_scores(self, x):
        new_x_shape = x.size()[:-1] + (self.num_attention_heads, self.attention_head_size)
        x = x.view(*new_x_shape)
        return x.permute(0, 2, 1, 3)

    def forward(self, hidden_states):
        mixed_query_layer = self.query(hidden_states)
        mixed_key_layer = self.key(hidden_states)
        mixed_value_layer = self.value(hidden_states)

        query_layer = self.transpose_for_scores(mixed_query_layer)
        key_layer = self.transpose_for_scores(mixed_key_layer)
        value_layer = self.transpose_for_scores(mixed_value_layer)

        attention_scores = torch.matmul(query_layer, key_layer.transpose(-1, -2))
        attention_scores = attention_scores / math.sqrt(self.attention_head_size)
        attention_probs = self.softmax(attention_scores)
        weights = attention_probs if self.vis else None
        attention_probs = self.attn_dropout(attention_probs)

        context_layer = torch.matmul(attention_probs, value_layer)
        context_layer = context_layer.permute(0, 2, 1, 3).contiguous()
        new_context_layer_shape = context_layer.size()[:-2] + (self.all_head_size,)
        context_layer = context_layer.view(*new_context_layer_shape)
        attention_output = self.out(context_layer)
        attention_output = self.proj_dropout(attention_output)
        return attention_output, weights


class Mlp(nn.Module):
    def __init__(self, config):
        super(Mlp, self).__init__()
        self.fc1 = Linear(config.hidden_size, config.transformer["mlp_dim"])
        self.fc2 = Linear(config.transformer["mlp_dim"], config.hidden_size)
        self.act_fn = ACT2FN["gelu"]
        self.dropout = Dropout(config.transformer["dropout_rate"])

        self._init_weights()

    def _init_weights(self):
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.normal_(self.fc1.bias, std=1e-6)
        nn.init.normal_(self.fc2.bias, std=1e-6)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act_fn(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.dropout(x)
        return x


class Embeddings(nn.Module):
    """Construct the embeddings from patch, position embeddings.
    """
    def __init__(self, config, img_size, in_channels=3):
        super(Embeddings, self).__init__()
        self.hybrid = None
        self.config = config
        img_size = _pair(img_size)

        if config.patches.get("grid") is not None:   # ResNet
            grid_size = config.patches["grid"]
            patch_size = (img_size[0] // 16 // grid_size[0], img_size[1] // 16 // grid_size[1])
            patch_size_real = (patch_size[0] * 16, patch_size[1] * 16)
            n_patches = (img_size[0] // patch_size_real[0]) * (img_size[1] // patch_size_real[1])  
            self.hybrid = True
        else:
            patch_size = _pair(config.patches["size"])
            n_patches = (img_size[0] // patch_size[0]) * (img_size[1] // patch_size[1])
            self.hybrid = False

        if self.hybrid:
            self.hybrid_model = ResNetV2(block_units=config.resnet.num_layers, width_factor=config.resnet.width_factor)
            in_channels = self.hybrid_model.width * 16
        self.patch_embeddings = Conv2d(in_channels=in_channels,
                                       out_channels=config.hidden_size,
                                       kernel_size=patch_size,
                                       stride=patch_size)
        self.position_embeddings = nn.Parameter(torch.zeros(1, n_patches, config.hidden_size))

        self.dropout = Dropout(config.transformer["dropout_rate"])


    def forward(self, x):
        if self.hybrid:
            x, features = self.hybrid_model(x)
        else:
            features = None
        x = self.patch_embeddings(x)  # (B, hidden. n_patches^(1/2), n_patches^(1/2))
        x = x.flatten(2)
        x = x.transpose(-1, -2)  # (B, n_patches, hidden)

        embeddings = x + self.position_embeddings
        embeddings = self.dropout(embeddings)
        return embeddings, features


class Block(nn.Module):
    def __init__(self, config, vis):
        super(Block, self).__init__()
        self.hidden_size = config.hidden_size
        self.attention_norm = LayerNorm(config.hidden_size, eps=1e-6)
        self.ffn_norm = LayerNorm(config.hidden_size, eps=1e-6)
        self.ffn = Mlp(config)
        self.attn = Attention(config, vis)

    def forward(self, x):
        h = x
        x = self.attention_norm(x)
        x, weights = self.attn(x)
        x = x + h

        h = x
        x = self.ffn_norm(x)
        x = self.ffn(x)
        x = x + h
        return x, weights

    def load_from(self, weights, n_block):
        ROOT = f"Transformer/encoderblock_{n_block}"
        with torch.no_grad():
            query_weight = np2th(weights[pjoin(ROOT, ATTENTION_Q, "kernel")]).view(self.hidden_size, self.hidden_size).t()
            key_weight = np2th(weights[pjoin(ROOT, ATTENTION_K, "kernel")]).view(self.hidden_size, self.hidden_size).t()
            value_weight = np2th(weights[pjoin(ROOT, ATTENTION_V, "kernel")]).view(self.hidden_size, self.hidden_size).t()
            out_weight = np2th(weights[pjoin(ROOT, ATTENTION_OUT, "kernel")]).view(self.hidden_size, self.hidden_size).t()

            query_bias = np2th(weights[pjoin(ROOT, ATTENTION_Q, "bias")]).view(-1)
            key_bias = np2th(weights[pjoin(ROOT, ATTENTION_K, "bias")]).view(-1)
            value_bias = np2th(weights[pjoin(ROOT, ATTENTION_V, "bias")]).view(-1)
            out_bias = np2th(weights[pjoin(ROOT, ATTENTION_OUT, "bias")]).view(-1)

            self.attn.query.weight.copy_(query_weight)
            self.attn.key.weight.copy_(key_weight)
            self.attn.value.weight.copy_(value_weight)
            self.attn.out.weight.copy_(out_weight)
            self.attn.query.bias.copy_(query_bias)
            self.attn.key.bias.copy_(key_bias)
            self.attn.value.bias.copy_(value_bias)
            self.attn.out.bias.copy_(out_bias)

            mlp_weight_0 = np2th(weights[pjoin(ROOT, FC_0, "kernel")]).t()
            mlp_weight_1 = np2th(weights[pjoin(ROOT, FC_1, "kernel")]).t()
            mlp_bias_0 = np2th(weights[pjoin(ROOT, FC_0, "bias")]).t()
            mlp_bias_1 = np2th(weights[pjoin(ROOT, FC_1, "bias")]).t()

            self.ffn.fc1.weight.copy_(mlp_weight_0)
            self.ffn.fc2.weight.copy_(mlp_weight_1)
            self.ffn.fc1.bias.copy_(mlp_bias_0)
            self.ffn.fc2.bias.copy_(mlp_bias_1)

            self.attention_norm.weight.copy_(np2th(weights[pjoin(ROOT, ATTENTION_NORM, "scale")]))
            self.attention_norm.bias.copy_(np2th(weights[pjoin(ROOT, ATTENTION_NORM, "bias")]))
            self.ffn_norm.weight.copy_(np2th(weights[pjoin(ROOT, MLP_NORM, "scale")]))
            self.ffn_norm.bias.copy_(np2th(weights[pjoin(ROOT, MLP_NORM, "bias")]))


class Encoder(nn.Module):
    def __init__(self, config, vis):
        super(Encoder, self).__init__()
        self.vis = vis
        self.layer = nn.ModuleList()
        self.encoder_norm = LayerNorm(config.hidden_size, eps=1e-6)
        for _ in range(config.transformer["num_layers"]):
            layer = Block(config, vis)
            self.layer.append(copy.deepcopy(layer))

    def forward(self, hidden_states):
        attn_weights = []
        for layer_block in self.layer:
            hidden_states, weights = layer_block(hidden_states)
            if self.vis:
                attn_weights.append(weights)
        encoded = self.encoder_norm(hidden_states)
        return encoded, attn_weights


class Transformer(nn.Module):
    def __init__(self, config, img_size, vis):
        super(Transformer, self).__init__()
        self.embeddings = Embeddings(config, img_size=img_size)
        self.encoder = Encoder(config, vis)

    def forward(self, input_ids):
        embedding_output, features = self.embeddings(input_ids)
        encoded, attn_weights = self.encoder(embedding_output)  # (B, n_patch, hidden)
        return encoded, attn_weights, features


class Conv2dReLU(nn.Sequential):
    def __init__(
            self,
            in_channels,
            out_channels,
            kernel_size,
            padding=0,
            stride=1,
            use_batchnorm=True,
    ):
        conv = nn.Conv2d(
            in_channels,
            out_channels,
            kernel_size,
            stride=stride,
            padding=padding,
            bias=not (use_batchnorm),
        )
        relu = nn.ReLU(inplace=True)

        bn = nn.BatchNorm2d(out_channels)

        super(Conv2dReLU, self).__init__(conv, bn, relu)


class DecoderBlock(nn.Module):
    def __init__(
            self,
            in_channels,
            out_channels,
            skip_channels=0,
            use_batchnorm=True,
    ):
        super().__init__()
        self.conv1 = Conv2dReLU(
            in_channels + skip_channels,
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )
        self.conv2 = Conv2dReLU(
            out_channels,
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )
        self.up = nn.UpsamplingBilinear2d(scale_factor=2)

    def forward(self, x, skip=None):
        x = self.up(x)
        if skip is not None:
            x = torch.cat([x, skip], dim=1)
        x = self.conv1(x)
        x = self.conv2(x)
        return x


class SegmentationHead(nn.Sequential):

    def __init__(self, in_channels, out_channels, kernel_size=3, upsampling=1):
        conv2d = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, padding=kernel_size // 2)
        upsampling = nn.UpsamplingBilinear2d(scale_factor=upsampling) if upsampling > 1 else nn.Identity()
        super().__init__(conv2d, upsampling)


class DecoderCup(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        head_channels = 512
        self.conv_more = Conv2dReLU(
            config.hidden_size,
            head_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=True,
        )
        decoder_channels = config.decoder_channels
        in_channels = [head_channels] + list(decoder_channels[:-1])
        out_channels = decoder_channels

        if self.config.n_skip != 0:
            skip_channels = self.config.skip_channels
            for i in range(4-self.config.n_skip):  # re-select the skip channels according to n_skip
                skip_channels[3-i]=0

        else:
            skip_channels=[0,0,0,0]

        blocks = [
            DecoderBlock(in_ch, out_ch, sk_ch) for in_ch, out_ch, sk_ch in zip(in_channels, out_channels, skip_channels)
        ]
        self.blocks = nn.ModuleList(blocks)

    def forward(self, hidden_states, features=None):
        B, n_patch, hidden = hidden_states.size()  # reshape from (B, n_patch, hidden) to (B, h, w, hidden)
        h, w = int(np.sqrt(n_patch)), int(np.sqrt(n_patch))
        x = hidden_states.permute(0, 2, 1)
        x = x.contiguous().view(B, hidden, h, w)
        x = self.conv_more(x)
        for i, decoder_block in enumerate(self.blocks):
            if features is not None:
                skip = features[i] if (i < self.config.n_skip) else None
            else:
                skip = None
            x = decoder_block(x, skip=skip)
        return x


class VisionTransformer(nn.Module):
    def __init__(self, config, img_size=224, num_classes=21843, zero_head=False, vis=False):
        super(VisionTransformer, self).__init__()
        self.num_classes = num_classes
        self.zero_head = zero_head
        self.classifier = config.classifier
        self.transformer = Transformer(config, img_size, vis)
        self.decoder = DecoderCup(config)
        self.segmentation_head = SegmentationHead(
            in_channels=config['decoder_channels'][-1],
            out_channels=config['n_classes'],
            kernel_size=3,
        )
        self.config = config

    def forward(self, x):
        if x.size()[1] == 1:
            x = x.repeat(1,3,1,1)
        x, attn_weights, features = self.transformer(x)  # (B, n_patch, hidden)
        x = self.decoder(x, features)
        logits = self.segmentation_head(x)
        return logits

    def load_from(self, weights):
        with torch.no_grad():

            res_weight = weights
            self.transformer.embeddings.patch_embeddings.weight.copy_(np2th(weights["embedding/kernel"], conv=True))
            self.transformer.embeddings.patch_embeddings.bias.copy_(np2th(weights["embedding/bias"]))

            self.transformer.encoder.encoder_norm.weight.copy_(np2th(weights["Transformer/encoder_norm/scale"]))
            self.transformer.encoder.encoder_norm.bias.copy_(np2th(weights["Transformer/encoder_norm/bias"]))

            posemb = np2th(weights["Transformer/posembed_input/pos_embedding"])

            posemb_new = self.transformer.embeddings.position_embeddings
            if posemb.size() == posemb_new.size():
                self.transformer.embeddings.position_embeddings.copy_(posemb)
            elif posemb.size()[1]-1 == posemb_new.size()[1]:
                posemb = posemb[:, 1:]
                self.transformer.embeddings.position_embeddings.copy_(posemb)
            else:
                logger.info("load_pretrained: resized variant: %s to %s" % (posemb.size(), posemb_new.size()))
                ntok_new = posemb_new.size(1)
                if self.classifier == "seg":
                    _, posemb_grid = posemb[:, :1], posemb[0, 1:]
                gs_old = int(np.sqrt(len(posemb_grid)))
                gs_new = int(np.sqrt(ntok_new))
                print('load_pretrained: grid-size from %s to %s' % (gs_old, gs_new))
                posemb_grid = posemb_grid.reshape(gs_old, gs_old, -1)
                zoom = (gs_new / gs_old, gs_new / gs_old, 1)
                posemb_grid = ndimage.zoom(posemb_grid, zoom, order=1)  # th2np
                posemb_grid = posemb_grid.reshape(1, gs_new * gs_new, -1)
                posemb = posemb_grid
                self.transformer.embeddings.position_embeddings.copy_(np2th(posemb))

            # Encoder whole
            for bname, block in self.transformer.encoder.named_children():
                for uname, unit in block.named_children():
                    unit.load_from(weights, n_block=uname)

            if self.transformer.embeddings.hybrid:
                self.transformer.embeddings.hybrid_model.root.conv.weight.copy_(np2th(res_weight["conv_root/kernel"], conv=True))
                gn_weight = np2th(res_weight["gn_root/scale"]).view(-1)
                gn_bias = np2th(res_weight["gn_root/bias"]).view(-1)
                self.transformer.embeddings.hybrid_model.root.gn.weight.copy_(gn_weight)
                self.transformer.embeddings.hybrid_model.root.gn.bias.copy_(gn_bias)

                for bname, block in self.transformer.embeddings.hybrid_model.body.named_children():
                    for uname, unit in block.named_children():
                        unit.load_from(res_weight, n_block=bname, n_unit=uname)
                        
CONFIGS = {
    'ViT-B_16': get_b16_config(),
    'ViT-B_32': get_b32_config(),
    'ViT-L_16': get_l16_config(),
    'ViT-L_32': get_l32_config(),
    'ViT-H_14': get_h14_config(),
    'R50-ViT-B_16': get_r50_b16_config(),
    'testing': get_testing(),
}

# %%
import numpy as np
import torch
from medpy import metric
from scipy.ndimage import zoom
import torch.nn as nn
import SimpleITK as sitk


class DiceLoss(nn.Module):
    def __init__(self, n_classes):
        super(DiceLoss, self).__init__()
        self.n_classes = n_classes

    def _one_hot_encoder(self, input_tensor):
        tensor_list = []
        for i in range(self.n_classes):
            temp_prob = input_tensor == i  # * torch.ones_like(input_tensor)
            tensor_list.append(temp_prob.unsqueeze(1))
        output_tensor = torch.cat(tensor_list, dim=1)
        return output_tensor.float()

    def _dice_loss(self, score, target):
        target = target.float()
        smooth = 1e-5
        intersect = torch.sum(score * target)
        y_sum = torch.sum(target * target)
        z_sum = torch.sum(score * score)
        loss = (2 * intersect + smooth) / (z_sum + y_sum + smooth)
        loss = 1 - loss
        return loss

    def forward(self, inputs, target, weight=None, softmax=False):
        if softmax:
            inputs = torch.softmax(inputs, dim=1)
        target = self._one_hot_encoder(target)
        if weight is None:
            weight = [1] * self.n_classes
        assert inputs.size() == target.size(), 'predict {} & target {} shape do not match'.format(inputs.size(), target.size())
        class_wise_dice = []
        loss = 0.0
        for i in range(0, self.n_classes):
            dice = self._dice_loss(inputs[:, i], target[:, i])
            class_wise_dice.append(1.0 - dice.item())
            loss += dice * weight[i]
        return loss / self.n_classes


def calculate_metric_percase(pred, gt):
    pred[pred > 0] = 1
    gt[gt > 0] = 1
    if pred.sum() > 0 and gt.sum()>0:
        dice = metric.binary.dc(pred, gt)
        hd95 = metric.binary.hd95(pred, gt)
        return dice, hd95
    elif pred.sum() > 0 and gt.sum()==0:
        return 1, 0
    else:
        return 0, 0


def test_single_volume(image, label, net, classes, patch_size=[256, 256], test_save_path=None, case=None, z_spacing=1):
    image, label = image.squeeze(0).cpu().detach().numpy(), label.squeeze(0).cpu().detach().numpy()
    if len(image.shape) == 3:
        prediction = np.zeros_like(label)
        for ind in range(image.shape[0]):
            slice = image[ind, :, :]
            x, y = slice.shape[0], slice.shape[1]
            if x != patch_size[0] or y != patch_size[1]:
                slice = zoom(slice, (patch_size[0] / x, patch_size[1] / y), order=3)  # previous using 0
            input = torch.from_numpy(slice).unsqueeze(0).unsqueeze(0).float().cuda()
            net.eval()
            with torch.no_grad():
                outputs = net(input)
                out = torch.argmax(torch.softmax(outputs, dim=1), dim=1).squeeze(0)
                out = out.cpu().detach().numpy()
                if x != patch_size[0] or y != patch_size[1]:
                    pred = zoom(out, (x / patch_size[0], y / patch_size[1]), order=0)
                else:
                    pred = out
                prediction[ind] = pred
    else:
        input = torch.from_numpy(image).unsqueeze(
            0).unsqueeze(0).float().cuda()
        net.eval()
        with torch.no_grad():
            out = torch.argmax(torch.softmax(net(input), dim=1), dim=1).squeeze(0)
            prediction = out.cpu().detach().numpy()
    metric_list = []
    for i in range(1, classes):
        metric_list.append(calculate_metric_percase(prediction == i, label == i))

    if test_save_path is not None:
        img_itk = sitk.GetImageFromArray(image.astype(np.float32))
        prd_itk = sitk.GetImageFromArray(prediction.astype(np.float32))
        lab_itk = sitk.GetImageFromArray(label.astype(np.float32))
        img_itk.SetSpacing((1, 1, z_spacing))
        prd_itk.SetSpacing((1, 1, z_spacing))
        lab_itk.SetSpacing((1, 1, z_spacing))
        sitk.WriteImage(prd_itk, test_save_path + '/'+case + "_pred.nii.gz")
        sitk.WriteImage(img_itk, test_save_path + '/'+ case + "_img.nii.gz")
        sitk.WriteImage(lab_itk, test_save_path + '/'+ case + "_gt.nii.gz")
    return metric_list

# %%
import argparse
import logging
import os
import random
import sys
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from tensorboardX import SummaryWriter
from torch.nn.modules.loss import CrossEntropyLoss
from torch.utils.data import DataLoader
from tqdm import tqdm
from torchvision import transforms

def worker_init_fn(worker_id):
    random.seed(1234 + worker_id)

def trainer_synapse(args, model, snapshot_path):
    logging.basicConfig(filename=snapshot_path + "/log.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
    logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
    logging.info(str(args))
    base_lr = args.base_lr
    num_classes = args.num_classes
    batch_size = args.batch_size * args.n_gpu
    # max_iterations = args.max_iterations
    db_train = Synapse_dataset(base_dir=args.root_path, list_dir=args.list_dir, split="train",
                               transform=transforms.Compose(
                                   [RandomGenerator(output_size=[args.img_size, args.img_size])]))
    print("The length of train set is: {}".format(len(db_train)))



    trainloader = DataLoader(db_train, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True,
                             worker_init_fn=worker_init_fn)
    if args.n_gpu > 1:
        model = nn.DataParallel(model)
    model.train()
    ce_loss = CrossEntropyLoss()
    dice_loss = DiceLoss(num_classes)
    optimizer = optim.SGD(model.parameters(), lr=base_lr, momentum=0.9, weight_decay=0.0001)
    writer = SummaryWriter(snapshot_path + '/log')
    iter_num = 0
    max_epoch = args.max_epochs
    max_iterations = args.max_epochs * len(trainloader)  # max_epoch = max_iterations // len(trainloader) + 1
    logging.info("{} iterations per epoch. {} max iterations ".format(len(trainloader), max_iterations))
    best_performance = 0.0
    iterator = tqdm(range(max_epoch), ncols=70)
    for epoch_num in iterator:
        for i_batch, sampled_batch in enumerate(trainloader):
            image_batch, label_batch = sampled_batch['image'], sampled_batch['label']
            image_batch, label_batch = image_batch.cuda(), label_batch.cuda()
            outputs = model(image_batch)
            loss_ce = ce_loss(outputs, label_batch[:].long())
            loss_dice = dice_loss(outputs, label_batch, softmax=True)
            loss = 0.5 * loss_ce + 0.5 * loss_dice
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lr_ = base_lr * (1.0 - iter_num / max_iterations) ** 0.9
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr_

            iter_num = iter_num + 1
            writer.add_scalar('info/lr', lr_, iter_num)
            writer.add_scalar('info/total_loss', loss, iter_num)
            writer.add_scalar('info/loss_ce', loss_ce, iter_num)

            logging.info('iteration %d : loss : %f, loss_ce: %f' % (iter_num, loss.item(), loss_ce.item()))

            if iter_num % 20 == 0:
                image = image_batch[1, 0:1, :, :]
                image = (image - image.min()) / (image.max() - image.min())
                writer.add_image('train/Image', image, iter_num)
                outputs = torch.argmax(torch.softmax(outputs, dim=1), dim=1, keepdim=True)
                writer.add_image('train/Prediction', outputs[1, ...] * 50, iter_num)
                labs = label_batch[1, ...].unsqueeze(0) * 50
                writer.add_image('train/GroundTruth', labs, iter_num)

        save_interval = 50  # int(max_epoch/6)
        if epoch_num > int(max_epoch / 2) and (epoch_num + 1) % save_interval == 0:
            save_mode_path = os.path.join(snapshot_path, 'epoch_' + str(epoch_num) + '.pth')
            torch.save(model.state_dict(), save_mode_path)
            logging.info("save model to {}".format(save_mode_path))

        if epoch_num >= max_epoch - 1:
            save_mode_path = os.path.join(snapshot_path, 'epoch_' + str(epoch_num) + '.pth')
            torch.save(model.state_dict(), save_mode_path)
            logging.info("save model to {}".format(save_mode_path))
            iterator.close()
            break

    writer.close()
    return "Training Finished!"

# %%
import argparse
import logging
import os
import random
import numpy as np
import torch
import torch.backends.cudnn as cudnn
import argparse

import torch
torch.cuda.empty_cache()


parser = argparse.ArgumentParser()
parser.add_argument('--root_path', type=str,
                    default='/content/gdrive/MyDrive/Research dataset/data/Synapse/train_npz', help='root dir for data')
parser.add_argument('--dataset', type=str,
                    default='Synapse', help='experiment_name')
parser.add_argument('--list_dir', type=str,
                    default='/content/gdrive/MyDrive/Research dataset/data/Synapse/TransUNet-main/lists/lists_Synapse', help='list dir')
parser.add_argument('--num_classes', type=int,
                    default=9, help='output channel of network')
parser.add_argument('--max_iterations', type=int,
                    default=30000, help='maximum epoch number to train')
parser.add_argument('--max_epochs', type=int,
                    default=150, help='maximum epoch number to train')
parser.add_argument('--batch_size', type=int,
                    default=8, help='batch_size per gpu')
parser.add_argument('--n_gpu', type=int, default=1, help='total gpu')
parser.add_argument('--deterministic', type=int,  default=1,
                    help='whether use deterministic training')
parser.add_argument('--base_lr', type=float,  default=0.01,
                    help='segmentation network learning rate')
parser.add_argument('--img_size', type=int,
                    default=224, help='input patch size of network input')
parser.add_argument('--seed', type=int,
                    default=1234, help='random seed')
parser.add_argument('--n_skip', type=int,
                    default=3, help='using number of skip-connect, default is num')
parser.add_argument('--vit_name', type=str,
                    default='R50-ViT-B_16', help='select one vit model')
parser.add_argument('--vit_patches_size', type=int,
                    default=16, help='vit_patches_size, default is 16')
parser.add_argument('-f')
args = parser.parse_args()


if __name__ == "__main__":
    if not args.deterministic:
        cudnn.benchmark = True
        cudnn.deterministic = False
    else:
        cudnn.benchmark = False
        cudnn.deterministic = True

    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.cuda.manual_seed(args.seed)
    dataset_name = args.dataset
    dataset_config = {
        'Synapse': {
            'root_path': '/content/gdrive/MyDrive/Research dataset/data/Synapse/train_npz',
            'list_dir': '/content/gdrive/MyDrive/Research dataset/data/Synapse/TransUNet-main/lists/lists_Synapse',
            'num_classes': 9,
        },
    }
    args.num_classes = dataset_config[dataset_name]['num_classes']
    args.root_path = dataset_config[dataset_name]['root_path']
    args.list_dir = dataset_config[dataset_name]['list_dir']
    args.is_pretrain = True
    args.exp = 'TU_' + dataset_name + str(args.img_size)
    snapshot_path = "/content/vit new/model/".format(args.exp, 'TU')
    snapshot_path = snapshot_path + '_pretrain' if args.is_pretrain else snapshot_path
    snapshot_path += '_' + args.vit_name
    snapshot_path = snapshot_path + '_skip' + str(args.n_skip)
    snapshot_path = snapshot_path + '_vitpatch' + str(args.vit_patches_size) if args.vit_patches_size!=16 else snapshot_path
    snapshot_path = snapshot_path+'_'+str(args.max_iterations)[0:2]+'k' if args.max_iterations != 30000 else snapshot_path
    snapshot_path = snapshot_path + '_epo' +str(args.max_epochs) if args.max_epochs != 30 else snapshot_path
    snapshot_path = snapshot_path+'_bs'+str(args.batch_size)
    snapshot_path = snapshot_path + '_lr' + str(args.base_lr) if args.base_lr != 0.01 else snapshot_path
    snapshot_path = snapshot_path + '_'+str(args.img_size)
    snapshot_path = snapshot_path + '_s'+str(args.seed) if args.seed!=1234 else snapshot_path

    if not os.path.exists(snapshot_path):
        os.makedirs(snapshot_path)
    config_vit=CONFIGS[args.vit_name]
    config_vit.n_classes = args.num_classes
    config_vit.n_skip = args.n_skip
    if args.vit_name.find('R50') != -1:
        config_vit.patches.grid = (int(args.img_size / args.vit_patches_size), int(args.img_size / args.vit_patches_size))
    net = VisionTransformer(config_vit, img_size=args.img_size, num_classes=config_vit.n_classes).cuda()
    net.load_from(weights=np.load(config_vit.pretrained_path))

    trainer = {'Synapse': trainer_synapse,}
    trainer[dataset_name](args, net, snapshot_path)
# Out:
# load_pretrained: grid-size from 24 to 14
# Namespace(base_lr=0.01, batch_size=8, dataset='Synapse', deterministic=1, exp='TU_Synapse224', f='/root/.local/share/jupyter/runtime/kernel-e2cab790-e5e2-4565-a281-e2a05706466a.json', img_size=224, is_pretrain=True, list_dir='/content/gdrive/MyDrive/Research dataset/data/Synapse/TransUNet-main/lists/lists_Synapse', max_epochs=150, max_iterations=30000, n_gpu=1, n_skip=3, num_classes=9, root_path='/content/gdrive/MyDrive/Research dataset/data/Synapse/train_npz', seed=1234, vit_name='R50-ViT-B_16', vit_patches_size=16)
# The length of train set is: 2211
# 277 iterations per epoch. 41550 max iterations
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|                                         | 0/150 [00:00<?, ?it/s]
# iteration 1 : loss : 1.468275, loss_ce: 2.016984
# iteration 2 : loss : 1.422202, loss_ce: 1.919402
# iteration 3 : loss : 1.340598, loss_ce: 1.752474
# iteration 4 : loss : 1.230367, loss_ce: 1.544818
# iteration 5 : loss : 1.109964, loss_ce: 1.311600
# iteration 6 : loss : 0.978269, loss_ce: 1.049563
# iteration 7 : loss : 0.880956, loss_ce: 0.892617
# iteration 8 : loss : 0.767395, loss_ce: 0.668236
# iteration 9 : loss : 0.682114, loss_ce: 0.511880
# iteration 10 : loss : 0.627963, loss_ce: 0.388992
# iteration 11 : loss : 0.611779, loss_ce: 0.377135
# iteration 12 : loss : 0.540724, loss_ce: 0.215962
# iteration 13 : loss : 0.606484, loss_ce: 0.350085
# iteration 14 : loss : 0.571307, loss_ce: 0.287340
# iteration 15 : loss : 0.532564, loss_ce: 0.220320
# iteration 16 : loss : 0.529753, loss_ce: 0.220624
# iteration 17 : loss : 0.528823, loss_ce: 0.214133
# iteration 18 : loss : 0.481405, loss_ce: 0.135836
# iteration 19 : loss : 0.491751, loss_ce: 0.130209
# iteration 20 : loss : 0.529603, loss_ce: 0.236514
# iteration 21 : loss : 0.567607, loss_ce: 0.298807
# iteration 22 : loss : 0.505371, loss_ce: 0.187878
# iteration 23 : loss : 0.472040, loss_ce: 0.132319
# iteration 24 : loss : 0.473250, loss_ce: 0.130337
# iteration 25 : loss : 0.503300, loss_ce: 0.189885
# iteration 26 : loss : 0.487507, loss_ce: 0.148875
# iteration 27 : loss : 0.521129, loss_ce: 0.221315
# iteration 28 : loss : 0.494677, loss_ce: 0.179715
# iteration 29 : loss : 0.469924, loss_ce: 0.137088
# iteration 30 : loss : 0.521592, loss_ce: 0.222970
# iteration 31 : loss : 0.489639, loss_ce: 0.170154
# iteration 32 : loss : 0.517268, loss_ce: 0.235845
# iteration 33 : loss : 0.468760, loss_ce: 0.158294
# iteration 34 : loss : 0.517697, loss_ce: 0.231845
# iteration 35 : loss : 0.534416, loss_ce: 0.267807
# iteration 36 : loss : 0.467458, loss_ce: 0.145408
# iteration 37 : loss : 0.479808, loss_ce: 0.136934
# iteration 38 : loss : 0.486796, loss_ce: 0.086747
# iteration 39 : loss : 0.538677, loss_ce: 0.242389
# iteration 40 : loss : 0.487741, loss_ce: 0.154544
# iteration 41 : loss : 0.530243, loss_ce: 0.234775
# iteration 42 : loss : 0.461325, loss_ce: 0.107363
# iteration 43 : loss : 0.542574, loss_ce: 0.278955
# iteration 44 : loss : 0.467709, loss_ce: 0.121457
# iteration 45 : loss : 0.497830, loss_ce: 0.196203
# iteration 46 : loss : 0.512285, loss_ce: 0.218434
# iteration 47 : loss : 0.504384, loss_ce: 0.201634
# iteration 48 : loss : 0.457021, loss_ce: 0.116030
# iteration 49 : loss : 0.452349, loss_ce: 0.110137
# iteration 50 : loss : 0.456858, loss_ce: 0.135278
# iteration 51 : loss : 0.598013, loss_ce: 0.355422
# iteration 52 : loss : 0.469397, loss_ce: 0.151042
# iteration 53 : loss : 0.528921, loss_ce: 0.248832
# iteration 54 : loss : 0.534345, loss_ce: 0.283370
# iteration 55 : loss : 0.489586, loss_ce: 0.180886
# iteration 56 : loss : 0.497574, loss_ce: 0.212938
# iteration 57 : loss : 0.473750, loss_ce: 0.148123
# iteration 58 : loss : 0.474308, loss_ce: 0.167669
# iteration 59 : loss : 0.530462, loss_ce: 0.260731
# iteration 60 : loss : 0.474597, loss_ce: 0.149325
# iteration 61 : loss : 0.446131, loss_ce: 0.064384
# iteration 62 : loss : 0.457393, loss_ce: 0.118029
# iteration 63 : loss : 0.536808, loss_ce: 0.236616
# iteration 64 : loss : 0.439124, loss_ce: 0.048933
# iteration 65 : loss : 0.436812, loss_ce: 0.069484
# iteration 66 : loss : 0.424507, loss_ce: 0.054838
# iteration 67 : loss : 0.471660, loss_ce: 0.145913
# iteration 68 : loss : 0.540131, loss_ce: 0.273207
# iteration 69 : loss : 0.509138, loss_ce: 0.242336
# iteration 70 : loss : 0.497783, loss_ce: 0.198357
# iteration 71 : loss : 0.487150, loss_ce: 0.175194
# iteration 72 : loss : 0.499915, loss_ce: 0.222517
# iteration 73 : loss : 0.480461, loss_ce: 0.157551
# iteration 74 : loss : 0.456102, loss_ce: 0.133708
# iteration 75 : loss : 0.499208, loss_ce: 0.225364
# iteration 76 : loss : 0.471366, loss_ce: 0.155929
# iteration 77 : loss : 0.456920, loss_ce: 0.128470
# iteration 78 : loss : 0.459572, loss_ce: 0.110624
# iteration 79 : loss : 0.510720, loss_ce: 0.203375
# iteration 80 : loss : 0.469074, loss_ce: 0.141528
# iteration 81 : loss : 0.492035, loss_ce: 0.162613
# iteration 82 : loss : 0.453370, loss_ce: 0.102341
# iteration 83 : loss : 0.439635, loss_ce: 0.102284
# iteration 84 : loss : 0.478620, loss_ce: 0.160203
# iteration 85 : loss : 0.470872, loss_ce: 0.143074
# iteration 86 : loss : 0.445930, loss_ce: 0.123376
# iteration 87 : loss : 0.447797, loss_ce: 0.125516
# iteration 88 : loss : 0.450669, loss_ce: 0.126346
# iteration 89 : loss : 0.472330, loss_ce: 0.168424
# iteration 90 : loss : 0.464544, loss_ce: 0.139375
# iteration 91 : loss : 0.498864, loss_ce: 0.217318
# iteration 92 : loss : 0.471501, loss_ce: 0.156025
# iteration 93 : loss : 0.462192, loss_ce: 0.144002
# iteration 94 : loss : 0.444736, loss_ce: 0.080050
# iteration 95 : loss : 0.488816, loss_ce: 0.197449
# iteration 96 : loss : 0.419563, loss_ce: 0.071536
# iteration 97 : loss : 0.500087, loss_ce: 0.223140
# iteration 98 : loss : 0.418297, loss_ce: 0.088733
# iteration 99 : loss : 0.429665, loss_ce: 0.083937
# iteration 100 : loss : 0.431312, loss_ce: 0.108170
# iteration 101 : loss : 0.419390, loss_ce: 0.065676
# iteration 102 : loss : 0.446409, loss_ce: 0.130177
# iteration 103 : loss : 0.429745, loss_ce: 0.101795
# iteration 104 : loss : 0.403223, loss_ce: 0.097752
# iteration 105 : loss : 0.509758, loss_ce: 0.228508
# iteration 106 : loss : 0.415655, loss_ce: 0.095129
# iteration 107 : loss : 0.433865, loss_ce: 0.144664
# iteration 108 : loss : 0.405544, loss_ce: 0.067690
# iteration 109 : loss : 0.414317, loss_ce: 0.073895
# iteration 110 : loss : 0.395715, loss_ce: 0.067370
# iteration 111 : loss : 0.428544, loss_ce: 0.130252
# iteration 112 : loss : 0.412579, loss_ce: 0.108434
# iteration 113 : loss : 0.483005, loss_ce: 0.086215
# iteration 114 : loss : 0.429867, loss_ce: 0.087901
# iteration 115 : loss : 0.435684, loss_ce: 0.128108
# iteration 116 : loss : 0.462922, loss_ce: 0.179876
# iteration 117 : loss : 0.425864, loss_ce: 0.113716
# iteration 118 : loss : 0.436682, loss_ce: 0.144217
# iteration 119 : loss : 0.461711, loss_ce: 0.187347
# iteration 120 : loss : 0.426301, loss_ce: 0.113007
# iteration 121 : loss : 0.471452, loss_ce: 0.215735
# iteration 122 : loss : 0.449209, loss_ce: 0.123460
# iteration 123 : loss : 0.460365, loss_ce: 0.118393
# iteration 124 : loss : 0.421170, loss_ce: 0.124613
# iteration 125 : loss : 0.440200, loss_ce: 0.161088
# iteration 126 : loss : 0.464995, loss_ce: 0.188904
# iteration 127 : loss : 0.409605, loss_ce: 0.067973
# iteration 128 : loss : 0.405332, loss_ce: 0.072004
# iteration 129 : loss : 0.428184, loss_ce: 0.119837
# iteration 130 : loss : 0.411679, loss_ce: 0.070751
# iteration 131 : loss : 0.442919, loss_ce: 0.131573
# iteration 132 : loss : 0.432614, loss_ce: 0.146110
# iteration 133 : loss : 0.486264, loss_ce: 0.238185
# iteration 134 : loss : 0.416687, loss_ce: 0.113940
# iteration 135 : loss : 0.408259, loss_ce: 0.127205
# iteration 136 : loss : 0.450029, loss_ce: 0.167577
# iteration 137 : loss : 0.419472, loss_ce: 0.122181
# iteration 138 : loss : 0.405129, loss_ce: 0.098176
# iteration 139 : loss : 0.453105, loss_ce: 0.158768
# iteration 140 : loss : 0.433180, loss_ce: 0.072274
# iteration 141 : loss : 0.398854, loss_ce: 0.087973
# iteration 142 : loss : 0.397856, loss_ce: 0.074912
# iteration 143 : loss : 0.419927, loss_ce: 0.105574
# iteration 144 : loss : 0.403241, loss_ce: 0.077293
# iteration 145 : loss : 0.449890, loss_ce: 0.148866
# iteration 146 : loss : 0.422383, loss_ce: 0.124456
# iteration 147 : loss : 0.428921, loss_ce: 0.078195
# iteration 148 : loss : 0.430509, loss_ce: 0.108309
# iteration 149 : loss : 0.418305, loss_ce: 0.128614
# iteration 150 : loss : 0.474023, loss_ce: 0.167102
# iteration 151 : loss : 0.410707, loss_ce: 0.081618
# iteration 152 : loss : 0.411052, loss_ce: 0.117563
# iteration 153 : loss : 0.431711, loss_ce: 0.140618
# iteration 154 : loss : 0.414698, loss_ce: 0.109082
# iteration 155 : loss : 0.431664, loss_ce: 0.158595
# iteration 156 : loss : 0.399132, loss_ce: 0.082159
# iteration 157 : loss : 0.413908, loss_ce: 0.120702
# iteration 158 : loss : 0.413360, loss_ce: 0.119202
# iteration 159 : loss : 0.397770, loss_ce: 0.084390
# iteration 160 : loss : 0.463091, loss_ce: 0.071396
# iteration 161 : loss : 0.396023, loss_ce: 0.067713
# iteration 162 : loss : 0.418128, loss_ce: 0.050737
# iteration 163 : loss : 0.537228, loss_ce: 0.292501
# iteration 164 : loss : 0.395961, loss_ce: 0.069718
# iteration 165 : loss : 0.415353, loss_ce: 0.112472
# iteration 166 : loss : 0.431934, loss_ce: 0.148548
# iteration 167 : loss : 0.423894, loss_ce: 0.134088
# iteration 168 : loss : 0.436719, loss_ce: 0.096127
# iteration 169 : loss : 0.472196, loss_ce: 0.068222
# iteration 170 : loss : 0.419023, loss_ce: 0.125352
# iteration 171 : loss : 0.423839, loss_ce: 0.132027
# iteration 172 : loss : 0.428811, loss_ce: 0.138018
# iteration 173 : loss : 0.405677, loss_ce: 0.073331
# iteration 174 : loss : 0.418295, loss_ce: 0.140246
# iteration 175 : loss : 0.415768, loss_ce: 0.130681
# iteration 176 : loss : 0.392734, loss_ce: 0.080696
# iteration 177 : loss : 0.391014, loss_ce: 0.097029
# iteration 178 : loss : 0.390008, loss_ce: 0.079785
# iteration 179 : loss : 0.430717, loss_ce: 0.158344
# iteration 180 : loss : 0.428835, loss_ce: 0.152857
# iteration 181 : loss : 0.418167, loss_ce: 0.122891
# iteration 182 : loss : 0.443305, loss_ce: 0.057431
# iteration 183 : loss : 0.395562, loss_ce: 0.068224
# iteration 184 : loss : 0.415050, loss_ce: 0.126753
# iteration 185 : loss : 0.400946, loss_ce: 0.108449
# iteration 186 : loss : 0.396457, loss_ce: 0.108337
# iteration 187 : loss : 0.390305, loss_ce: 0.097376
# iteration 188 : loss : 0.429886, loss_ce: 0.161895
# iteration 189 : loss : 0.405175, loss_ce: 0.108273
# iteration 190 : loss : 0.408784, loss_ce: 0.089256
# iteration 191 : loss : 0.425806, loss_ce: 0.152896
# iteration 192 : loss : 0.379766, loss_ce: 0.063903
# iteration 193 : loss : 0.401995, loss_ce: 0.113344
# iteration 194 : loss : 0.404834, loss_ce: 0.120071
# iteration 195 : loss : 0.407351, loss_ce: 0.097180
# iteration 196 : loss : 0.394463, loss_ce: 0.095193
# iteration 197 : loss : 0.430352, loss_ce: 0.082871
# iteration 198 : loss : 0.423245, loss_ce: 0.120095
# iteration 199 : loss : 0.398559, loss_ce: 0.113859
# iteration 200 : loss : 0.415773, loss_ce: 0.102640
# iteration 201 : loss : 0.413530, loss_ce: 0.093860
# iteration 202 : loss : 0.448676, loss_ce: 0.136635
# iteration 203 : loss : 0.449452, loss_ce: 0.151851
# iteration 204 : loss : 0.427501, loss_ce: 0.149261
# iteration 205 : loss : 0.400545, loss_ce: 0.095122
# iteration 206 : loss : 0.438739, loss_ce: 0.112630
# iteration 207 : loss : 0.413852, loss_ce: 0.131410
# iteration 208 : loss : 0.386758, loss_ce: 0.082000
# iteration 209 : loss : 0.432969, loss_ce: 0.155206
# iteration 210 : loss : 0.400582, loss_ce: 0.079860
# iteration 211 : loss : 0.375802, loss_ce: 0.063971
# iteration 212 : loss : 0.378145, loss_ce: 0.063259
# iteration 213 : loss : 0.389182, loss_ce: 0.077937
# iteration 214 : loss : 0.413151, loss_ce: 0.109734
# iteration 215 : loss : 0.395306, loss_ce: 0.061130
# iteration 216 : loss : 0.391560, loss_ce: 0.089410
# iteration 217 : loss : 0.407609, loss_ce: 0.090159
# iteration 218 : loss : 0.393386, loss_ce: 0.060647
# iteration 219 : loss : 0.395784, loss_ce: 0.108358
# iteration 220 : loss : 0.421448, loss_ce: 0.150910
# iteration 221 : loss : 0.421035, loss_ce: 0.086758
# iteration 222 : loss : 0.390133, loss_ce: 0.076387
# iteration 223 : loss : 0.421103, loss_ce: 0.074950
# iteration 224 : loss : 0.454999, loss_ce: 0.187889
# iteration 225 : loss : 0.409639, loss_ce: 0.062999
# iteration 226 : loss : 0.422089, loss_ce: 0.121680
# iteration 227 : loss : 0.401604, loss_ce: 0.076964
# iteration 228 : loss : 0.409226, loss_ce: 0.121153
# iteration 229 : loss : 0.373293, loss_ce: 0.066867
# iteration 230 : loss : 0.378873, loss_ce: 0.073480
# iteration 231 : loss : 0.418324, loss_ce: 0.150455
# iteration 232 : loss : 0.386007, loss_ce: 0.084885
# iteration 233 : loss : 0.366929, loss_ce: 0.062718
# iteration 234 : loss : 0.427412, loss_ce: 0.149090
# iteration 235 : loss : 0.386818, loss_ce: 0.080010
# iteration 236 : loss : 0.382101, loss_ce: 0.056997
# iteration 237 : loss : 0.388676, loss_ce: 0.072821
# iteration 238 : loss : 0.383617, loss_ce: 0.067409
# iteration 239 : loss : 0.376699, loss_ce: 0.055214
# iteration 240 : loss : 0.374436, loss_ce: 0.056827
# iteration 241 : loss : 0.389816, loss_ce: 0.048640
# iteration 242 : loss : 0.400849, loss_ce: 0.103939
# iteration 243 : loss : 0.405248, loss_ce: 0.107785
# iteration 244 : loss : 0.392474, loss_ce: 0.050693
# iteration 245 : loss : 0.386671, loss_ce: 0.089282
# iteration 246 : loss : 0.386926, loss_ce: 0.072620
# iteration 247 : loss : 0.376276, loss_ce: 0.056524
# iteration 248 : loss : 0.414998, loss_ce: 0.136793
# iteration 249 : loss : 0.389235, loss_ce: 0.092743
# iteration 250 : loss : 0.399914, loss_ce: 0.101761
# iteration 251 : loss : 0.404617, loss_ce: 0.129663
# iteration 252 : loss : 0.392716, loss_ce: 0.100374
# iteration 253 : loss : 0.390827, loss_ce: 0.089202
# iteration 254 : loss : 0.431569, loss_ce: 0.159795
# iteration 255 : loss : 0.388730, loss_ce: 0.101954
# iteration 256 : loss : 0.414318, loss_ce: 0.069156
# iteration 257 : loss : 0.392201, loss_ce: 0.077209
# iteration 258 : loss : 0.393989, loss_ce: 0.083669
# iteration 259 : loss : 0.379997, loss_ce: 0.074026
# iteration 260 : loss : 0.369108, loss_ce: 0.066646
# iteration 261 : loss : 0.388154, loss_ce: 0.111606
# iteration 262 : loss : 0.394965, loss_ce: 0.059535
# iteration 263 : loss : 0.370215, loss_ce: 0.073569
# iteration 264 : loss : 0.372246, loss_ce: 0.050545
# iteration 265 : loss : 0.390564, loss_ce: 0.083633
# iteration 266 : loss : 0.391079, loss_ce: 0.099090
# iteration 267 : loss : 0.386287, loss_ce: 0.080158
# iteration 268 : loss : 0.419333, loss_ce: 0.147393
# iteration 269 : loss : 0.396514, loss_ce: 0.097388
# iteration 270 : loss : 0.391777, loss_ce: 0.043719
# iteration 271 : loss : 0.391118, loss_ce: 0.111558
# iteration 272 : loss : 0.389500, loss_ce: 0.098982
# iteration 273 : loss : 0.395059, loss_ce: 0.058338
# iteration 274 : loss : 0.378998, loss_ce: 0.060289
# iteration 275 : loss : 0.420571, loss_ce: 0.144585
# iteration 276 : loss : 0.378954, loss_ce: 0.069731
# iteration 277 : loss : 0.440164, loss_ce: 0.147230
#   1%|▏                            | 1/150 [06:12<15:24:48, 372.40s/it]
# iteration 278 : loss : 0.405104, loss_ce: 0.120929
# iteration 279 : loss : 0.374235, loss_ce: 0.060382
# iteration 280 : loss : 0.381231, loss_ce: 0.056972
# iteration 281 : loss : 0.398134, loss_ce: 0.048224
# iteration 282 : loss : 0.384276, loss_ce: 0.075379
# iteration 283 : loss : 0.389093, loss_ce: 0.032707
# iteration 284 : loss : 0.386241, loss_ce: 0.087759
# iteration 285 : loss : 0.362368, loss_ce: 0.056782
# iteration 286 : loss : 0.395687, loss_ce: 0.098097
# iteration 287 : loss : 0.408468, loss_ce: 0.049454
# iteration 288 : loss : 0.406117, loss_ce: 0.120650
# iteration 289 : loss : 0.417711, loss_ce: 0.118100
# iteration 290 : loss : 0.362508, loss_ce: 0.044998
# iteration 291 : loss : 0.383756, loss_ce: 0.083662
# iteration 292 : loss : 0.380092, loss_ce: 0.042203
# iteration 293 : loss : 0.386939, loss_ce: 0.092386
# iteration 294 : loss : 0.422015, loss_ce: 0.173041
# iteration 295 : loss : 0.395928, loss_ce: 0.106965
# iteration 296 : loss : 0.389114, loss_ce: 0.058342
# iteration 297 : loss : 0.380941, loss_ce: 0.060108
# iteration 298 : loss : 0.384682, loss_ce: 0.095427
# iteration 299 : loss : 0.403296, loss_ce: 0.068966
# iteration 300 : loss : 0.387609, loss_ce: 0.020371
# iteration 301 : loss : 0.391230, loss_ce: 0.074293
# iteration 302 : loss : 0.369132, loss_ce: 0.050145
# iteration 303 : loss : 0.376842, loss_ce: 0.028724
# iteration 304 : loss : 0.383092, loss_ce: 0.090057
# iteration 305 : loss : 0.360915, loss_ce: 0.056537
# iteration 306 : loss : 0.390143, loss_ce: 0.104379
# iteration 307 : loss : 0.365712, loss_ce: 0.052481
# iteration 308 : loss : 0.391848, loss_ce: 0.104645
# iteration 309 : loss : 0.365717, loss_ce: 0.069255
# iteration 310 : loss : 0.386253, loss_ce: 0.096540
# iteration 311 : loss : 0.391133, loss_ce: 0.102155
# iteration 312 : loss : 0.377549, loss_ce: 0.095968
# iteration 313 : loss : 0.396798, loss_ce: 0.120435
# iteration 314 : loss : 0.384839, loss_ce: 0.107155
# iteration 315 : loss : 0.399171, loss_ce: 0.094203
# iteration 316 : loss : 0.376520, loss_ce: 0.090247
# iteration 317 : loss : 0.392603, loss_ce: 0.091741
# iteration 318 : loss : 0.407463, loss_ce: 0.144295
# iteration 319 : loss : 0.372758, loss_ce: 0.085364
# iteration 320 : loss : 0.359189, loss_ce: 0.042535
# iteration 321 : loss : 0.393035, loss_ce: 0.108195
# iteration 322 : loss : 0.387207, loss_ce: 0.089109
# iteration 323 : loss : 0.360180, loss_ce: 0.063216
# iteration 324 : loss : 0.374762, loss_ce: 0.065605
# iteration 325 : loss : 0.390593, loss_ce: 0.032231
# iteration 326 : loss : 0.380103, loss_ce: 0.089330
# iteration 327 : loss : 0.367267, loss_ce: 0.073331
# iteration 328 : loss : 0.373175, loss_ce: 0.064665
# iteration 329 : loss : 0.384313, loss_ce: 0.085639
# iteration 330 : loss : 0.383089, loss_ce: 0.039028
# iteration 331 : loss : 0.388866, loss_ce: 0.104374
# iteration 332 : loss : 0.381574, loss_ce: 0.076128
# iteration 333 : loss : 0.394075, loss_ce: 0.081723
# iteration 334 : loss : 0.418625, loss_ce: 0.142647
# iteration 335 : loss : 0.367470, loss_ce: 0.073833
# iteration 336 : loss : 0.424906, loss_ce: 0.180874
# iteration 337 : loss : 0.386701, loss_ce: 0.119476
# iteration 338 : loss : 0.364813, loss_ce: 0.091159
# iteration 339 : loss : 0.415208, loss_ce: 0.128817
# iteration 340 : loss : 0.396062, loss_ce: 0.108955
# iteration 341 : loss : 0.391104, loss_ce: 0.113547
# iteration 342 : loss : 0.383144, loss_ce: 0.041035
# iteration 343 : loss : 0.379540, loss_ce: 0.075436
# iteration 344 : loss : 0.417976, loss_ce: 0.039550
# iteration 345 : loss : 0.375332, loss_ce: 0.088592
# iteration 346 : loss : 0.375719, loss_ce: 0.071851
# iteration 347 : loss : 0.382179, loss_ce: 0.066268
# iteration 348 : loss : 0.372210, loss_ce: 0.040563
# iteration 349 : loss : 0.348388, loss_ce: 0.050831
# iteration 350 : loss : 0.387133, loss_ce: 0.034518
# iteration 351 : loss : 0.389864, loss_ce: 0.108463
# iteration 352 : loss : 0.367343, loss_ce: 0.034859
# iteration 353 : loss : 0.366511, loss_ce: 0.066223
# iteration 354 : loss : 0.352171, loss_ce: 0.030709
# iteration 355 : loss : 0.430361, loss_ce: 0.180260
# iteration 356 : loss : 0.377746, loss_ce: 0.092019
# iteration 357 : loss : 0.388171, loss_ce: 0.122168
# iteration 358 : loss : 0.372282, loss_ce: 0.102656
# iteration 359 : loss : 0.374798, loss_ce: 0.106326
# iteration 360 : loss : 0.381356, loss_ce: 0.088424
# iteration 361 : loss : 0.381278, loss_ce: 0.091625
# iteration 362 : loss : 0.449971, loss_ce: 0.033402
# iteration 363 : loss : 0.360292, loss_ce: 0.064492
# iteration 364 : loss : 0.442258, loss_ce: 0.023562
# iteration 365 : loss : 0.436120, loss_ce: 0.186373
# iteration 366 : loss : 0.367532, loss_ce: 0.080648
# iteration 367 : loss : 0.384018, loss_ce: 0.044512
# iteration 368 : loss : 0.426484, loss_ce: 0.038491
# iteration 369 : loss : 0.409269, loss_ce: 0.151524
# iteration 370 : loss : 0.360065, loss_ce: 0.056331
# iteration 371 : loss : 0.388364, loss_ce: 0.123696
# iteration 372 : loss : 0.366386, loss_ce: 0.059133
# iteration 373 : loss : 0.385562, loss_ce: 0.094280
# iteration 374 : loss : 0.411164, loss_ce: 0.078484
# iteration 375 : loss : 0.441312, loss_ce: 0.172248
# iteration 376 : loss : 0.361405, loss_ce: 0.038797
# iteration 377 : loss : 0.405492, loss_ce: 0.144939
# iteration 378 : loss : 0.416537, loss_ce: 0.043474
# iteration 379 : loss : 0.408748, loss_ce: 0.064663
# iteration 380 : loss : 0.403066, loss_ce: 0.102857
# iteration 381 : loss : 0.418174, loss_ce: 0.135704
# iteration 382 : loss : 0.402869, loss_ce: 0.122462
# iteration 383 : loss : 0.423697, loss_ce: 0.150542
# iteration 384 : loss : 0.380964, loss_ce: 0.071053
# iteration 385 : loss : 0.416000, loss_ce: 0.159837
# iteration 386 : loss : 0.378647, loss_ce: 0.126987
# iteration 387 : loss : 0.399086, loss_ce: 0.142172
# iteration 388 : loss : 0.419637, loss_ce: 0.079840
# iteration 389 : loss : 0.364109, loss_ce: 0.111706
# iteration 390 : loss : 0.384000, loss_ce: 0.117355
# iteration 391 : loss : 0.354706, loss_ce: 0.060801
# iteration 392 : loss : 0.379118, loss_ce: 0.090452
# iteration 393 : loss : 0.447515, loss_ce: 0.056535
# iteration 394 : loss : 0.365188, loss_ce: 0.099767
# iteration 395 : loss : 0.379397, loss_ce: 0.057438
# iteration 396 : loss : 0.406852, loss_ce: 0.144093
# iteration 397 : loss : 0.326422, loss_ce: 0.037392
# iteration 398 : loss : 0.410824, loss_ce: 0.058348
# iteration 399 : loss : 0.376961, loss_ce: 0.090492
# iteration 400 : loss : 0.377714, loss_ce: 0.116831
# iteration 401 : loss : 0.373703, loss_ce: 0.035919
# iteration 402 : loss : 0.347010, loss_ce: 0.048177
# iteration 403 : loss : 0.385693, loss_ce: 0.109569
# iteration 404 : loss : 0.366329, loss_ce: 0.107942
# iteration 405 : loss : 0.370800, loss_ce: 0.102498
# iteration 406 : loss : 0.386104, loss_ce: 0.131378
# iteration 407 : loss : 0.356271, loss_ce: 0.068884
# iteration 408 : loss : 0.369531, loss_ce: 0.054610
# iteration 409 : loss : 0.355630, loss_ce: 0.076633
# iteration 410 : loss : 0.398951, loss_ce: 0.152116
# iteration 411 : loss : 0.393959, loss_ce: 0.033361
# iteration 412 : loss : 0.365649, loss_ce: 0.077515
# iteration 413 : loss : 0.377214, loss_ce: 0.122827
# iteration 414 : loss : 0.381238, loss_ce: 0.129888
# iteration 415 : loss : 0.340797, loss_ce: 0.072652
# iteration 416 : loss : 0.339009, loss_ce: 0.067704
# iteration 417 : loss : 0.362148, loss_ce: 0.043513
# iteration 418 : loss : 0.350465, loss_ce: 0.080691
# iteration 419 : loss : 0.378364, loss_ce: 0.075240
# iteration 420 : loss : 0.365730, loss_ce: 0.094302
# iteration 421 : loss : 0.356541, loss_ce: 0.086864
# iteration 422 : loss : 0.343474, loss_ce: 0.060953
# iteration 423 : loss : 0.372065, loss_ce: 0.055245
# iteration 424 : loss : 0.339449, loss_ce: 0.089047
# iteration 425 : loss : 0.396015, loss_ce: 0.085636
# iteration 426 : loss : 0.321225, loss_ce: 0.049398
# iteration 427 : loss : 0.369733, loss_ce: 0.084880
# iteration 428 : loss : 0.356212, loss_ce: 0.068433
# iteration 429 : loss : 0.377831, loss_ce: 0.111846
# iteration 430 : loss : 0.397305, loss_ce: 0.103534
# iteration 431 : loss : 0.375811, loss_ce: 0.110233
# iteration 432 : loss : 0.393418, loss_ce: 0.095693
# iteration 433 : loss : 0.368740, loss_ce: 0.104328
# iteration 434 : loss : 0.373819, loss_ce: 0.099552
# iteration 435 : loss : 0.336132, loss_ce: 0.062174
# iteration 436 : loss : 0.409734, loss_ce: 0.149815
# iteration 437 : loss : 0.370489, loss_ce: 0.050860
# iteration 438 : loss : 0.348241, loss_ce: 0.052249
# iteration 439 : loss : 0.370049, loss_ce: 0.119024
# iteration 440 : loss : 0.378779, loss_ce: 0.089864
# iteration 441 : loss : 0.355874, loss_ce: 0.097319
# iteration 442 : loss : 0.393420, loss_ce: 0.059807
# iteration 443 : loss : 0.345518, loss_ce: 0.050799
# iteration 444 : loss : 0.379541, loss_ce: 0.066711
# iteration 445 : loss : 0.386833, loss_ce: 0.066638
# iteration 446 : loss : 0.378900, loss_ce: 0.059224
# iteration 447 : loss : 0.388821, loss_ce: 0.096277
# iteration 448 : loss : 0.367740, loss_ce: 0.118301
# iteration 449 : loss : 0.382610, loss_ce: 0.093637
# iteration 450 : loss : 0.355061, loss_ce: 0.043648
# iteration 451 : loss : 0.398132, loss_ce: 0.087755
# iteration 452 : loss : 0.380778, loss_ce: 0.024879
# iteration 453 : loss : 0.332304, loss_ce: 0.056852
# iteration 454 : loss : 0.336313, loss_ce: 0.040353
# iteration 455 : loss : 0.340866, loss_ce: 0.080117
# iteration 456 : loss : 0.343783, loss_ce: 0.050076
# iteration 457 : loss : 0.323080, loss_ce: 0.067939
# iteration 458 : loss : 0.395295, loss_ce: 0.106747
# iteration 459 : loss : 0.394158, loss_ce: 0.046468
# iteration 460 : loss : 0.352105, loss_ce: 0.092494
# iteration 461 : loss : 0.347692, loss_ce: 0.102103
# iteration 462 : loss : 0.329862, loss_ce: 0.053933
# iteration 463 : loss : 0.358025, loss_ce: 0.097657
# iteration 464 : loss : 0.366303, loss_ce: 0.050646
# iteration 465 : loss : 0.333102, loss_ce: 0.069172
# iteration 466 : loss : 0.341191, loss_ce: 0.071291
# iteration 467 : loss : 0.361854, loss_ce: 0.060685
# iteration 468 : loss : 0.356160, loss_ce: 0.098484
# iteration 469 : loss : 0.342957, loss_ce: 0.059753
# iteration 470 : loss : 0.343260, loss_ce: 0.074860
# iteration 471 : loss : 0.342860, loss_ce: 0.080826
# iteration 472 : loss : 0.362007, loss_ce: 0.083882
# iteration 473 : loss : 0.336515, loss_ce: 0.070806
# iteration 474 : loss : 0.345223, loss_ce: 0.087046
# iteration 475 : loss : 0.353267, loss_ce: 0.086596
# iteration 476 : loss : 0.382546, loss_ce: 0.036104
# iteration 477 : loss : 0.352157, loss_ce: 0.103428
# iteration 478 : loss : 0.341172, loss_ce: 0.102029
# iteration 479 : loss : 0.347208, loss_ce: 0.090909
# iteration 480 : loss : 0.439021, loss_ce: 0.110121
# iteration 481 : loss : 0.343700, loss_ce: 0.085233
# iteration 482 : loss : 0.359217, loss_ce: 0.069477
# iteration 483 : loss : 0.313486, loss_ce: 0.033758
# iteration 484 : loss : 0.411238, loss_ce: 0.029719
# iteration 485 : loss : 0.362824, loss_ce: 0.104803
# iteration 486 : loss : 0.354149, loss_ce: 0.050874
# iteration 487 : loss : 0.383048, loss_ce: 0.112605
# iteration 488 : loss : 0.442983, loss_ce: 0.052764
# iteration 489 : loss : 0.338665, loss_ce: 0.083296
# iteration 490 : loss : 0.365744, loss_ce: 0.115188
# iteration 491 : loss : 0.359144, loss_ce: 0.084571
# iteration 492 : loss : 0.329095, loss_ce: 0.064997
# iteration 493 : loss : 0.325441, loss_ce: 0.043913
# iteration 494 : loss : 0.364706, loss_ce: 0.084925
# iteration 495 : loss : 0.372333, loss_ce: 0.086114
# iteration 496 : loss : 0.364635, loss_ce: 0.111450
# iteration 497 : loss : 0.406195, loss_ce: 0.116132
# iteration 498 : loss : 0.344547, loss_ce: 0.071270
# iteration 499 : loss : 0.341553, loss_ce: 0.064384
# iteration 500 : loss : 0.342378, loss_ce: 0.075405
# iteration 501 : loss : 0.341933, loss_ce: 0.076605
# iteration 502 : loss : 0.335026, loss_ce: 0.090972
# iteration 503 : loss : 0.396752, loss_ce: 0.057467
# iteration 504 : loss : 0.381613, loss_ce: 0.021662
# iteration 505 : loss : 0.353355, loss_ce: 0.086511
# iteration 506 : loss : 0.384395, loss_ce: 0.120231
# iteration 507 : loss : 0.386169, loss_ce: 0.143911
# iteration 508 : loss : 0.359162, loss_ce: 0.077472
# iteration 509 : loss : 0.347029, loss_ce: 0.088125
# iteration 510 : loss : 0.316451, loss_ce: 0.046278
# iteration 511 : loss : 0.341916, loss_ce: 0.084930
# iteration 512 : loss : 0.353420, loss_ce: 0.108962
# iteration 513 : loss : 0.337933, loss_ce: 0.057867
# iteration 514 : loss : 0.350427, loss_ce: 0.064556
# iteration 515 : loss : 0.440787, loss_ce: 0.013780
# iteration 516 : loss : 0.395191, loss_ce: 0.042585
# iteration 517 : loss : 0.354555, loss_ce: 0.105274
# iteration 518 : loss : 0.348272, loss_ce: 0.063238
# iteration 519 : loss : 0.348525, loss_ce: 0.083130
# iteration 520 : loss : 0.352770, loss_ce: 0.087866
# iteration 521 : loss : 0.331321, loss_ce: 0.069732
# iteration 522 : loss : 0.337080, loss_ce: 0.089494
# iteration 523 : loss : 0.335663, loss_ce: 0.062334
# iteration 524 : loss : 0.365613, loss_ce: 0.050935
# iteration 525 : loss : 0.315403, loss_ce: 0.059636
# iteration 526 : loss : 0.329597, loss_ce: 0.089061
# iteration 527 : loss : 0.319762, loss_ce: 0.060329
# iteration 528 : loss : 0.387438, loss_ce: 0.136549
# iteration 529 : loss : 0.309714, loss_ce: 0.067405
# iteration 530 : loss : 0.355957, loss_ce: 0.118175
# iteration 531 : loss : 0.366788, loss_ce: 0.021142
# iteration 532 : loss : 0.327448, loss_ce: 0.063251
# iteration 533 : loss : 0.327526, loss_ce: 0.052568
# iteration 534 : loss : 0.340014, loss_ce: 0.083566
# iteration 535 : loss : 0.323458, loss_ce: 0.064965
# iteration 536 : loss : 0.338257, loss_ce: 0.076428
# iteration 537 : loss : 0.342483, loss_ce: 0.036259
# iteration 538 : loss : 0.338090, loss_ce: 0.101103
# iteration 539 : loss : 0.395550, loss_ce: 0.065153
# iteration 540 : loss : 0.334092, loss_ce: 0.086374
# iteration 541 : loss : 0.367660, loss_ce: 0.075249
# iteration 542 : loss : 0.335229, loss_ce: 0.060281
# iteration 543 : loss : 0.339720, loss_ce: 0.097665
# iteration 544 : loss : 0.324033, loss_ce: 0.063267
# iteration 545 : loss : 0.357370, loss_ce: 0.094915
# iteration 546 : loss : 0.314356, loss_ce: 0.054681
# iteration 547 : loss : 0.317624, loss_ce: 0.063329
# iteration 548 : loss : 0.303400, loss_ce: 0.058816
# iteration 549 : loss : 0.298635, loss_ce: 0.026690
# iteration 550 : loss : 0.337132, loss_ce: 0.079763
# iteration 551 : loss : 0.310928, loss_ce: 0.040455
# iteration 552 : loss : 0.311826, loss_ce: 0.047762
# iteration 553 : loss : 0.332789, loss_ce: 0.041007
# iteration 554 : loss : 0.392094, loss_ce: 0.024722
#   1%|▍                            | 2/150 [12:11<14:58:52, 364.41s/it]
# iteration 555 : loss : 0.387257, loss_ce: 0.078886
# iteration 556 : loss : 0.324593, loss_ce: 0.046758
# iteration 557 : loss : 0.329142, loss_ce: 0.042726
# iteration 558 : loss : 0.335840, loss_ce: 0.126460
# iteration 559 : loss : 0.316285, loss_ce: 0.053295
# iteration 560 : loss : 0.338715, loss_ce: 0.076553
# iteration 561 : loss : 0.297041, loss_ce: 0.038305
# iteration 562 : loss : 0.300361, loss_ce: 0.048643
# iteration 563 : loss : 0.310252, loss_ce: 0.062671
# iteration 564 : loss : 0.338841, loss_ce: 0.066349
# iteration 565 : loss : 0.325618, loss_ce: 0.052178
# iteration 566 : loss : 0.314468, loss_ce: 0.074034
# iteration 567 : loss : 0.320017, loss_ce: 0.050773
# iteration 568 : loss : 0.319468, loss_ce: 0.071588
# iteration 569 : loss : 0.383543, loss_ce: 0.059830
# iteration 570 : loss : 0.309302, loss_ce: 0.030100
# iteration 571 : loss : 0.343457, loss_ce: 0.058344
# iteration 572 : loss : 0.293136, loss_ce: 0.049745
# iteration 573 : loss : 0.330732, loss_ce: 0.074671
# iteration 574 : loss : 0.335426, loss_ce: 0.037459
# iteration 575 : loss : 0.333017, loss_ce: 0.090006
# iteration 576 : loss : 0.278580, loss_ce: 0.027559
# iteration 577 : loss : 0.339752, loss_ce: 0.099571
# iteration 578 : loss : 0.365537, loss_ce: 0.081783
# iteration 579 : loss : 0.293190, loss_ce: 0.052575
# iteration 580 : loss : 0.352407, loss_ce: 0.109776
# iteration 581 : loss : 0.304960, loss_ce: 0.070585
# iteration 582 : loss : 0.323859, loss_ce: 0.072501
# iteration 583 : loss : 0.318881, loss_ce: 0.091556
# iteration 584 : loss : 0.297223, loss_ce: 0.042102
# iteration 585 : loss : 0.334201, loss_ce: 0.107706
# iteration 586 : loss : 0.449599, loss_ce: 0.010206
# iteration 587 : loss : 0.381806, loss_ce: 0.131381
# iteration 588 : loss : 0.323372, loss_ce: 0.075469
# iteration 589 : loss : 0.292127, loss_ce: 0.057170
# iteration 590 : loss : 0.318317, loss_ce: 0.046059
# iteration 591 : loss : 0.313584, loss_ce: 0.081487
# iteration 592 : loss : 0.337765, loss_ce: 0.057816
# iteration 593 : loss : 0.299953, loss_ce: 0.062104
# iteration 594 : loss : 0.336442, loss_ce: 0.043557
# iteration 595 : loss : 0.367916, loss_ce: 0.167122
# iteration 596 : loss : 0.315024, loss_ce: 0.040135
# iteration 597 : loss : 0.333343, loss_ce: 0.103549
# iteration 598 : loss : 0.323105, loss_ce: 0.091837
# iteration 599 : loss : 0.333072, loss_ce: 0.067020
# iteration 600 : loss : 0.338760, loss_ce: 0.079688
# iteration 601 : loss : 0.323995, loss_ce: 0.111370
# iteration 602 : loss : 0.323682, loss_ce: 0.107998
# iteration 603 : loss : 0.330470, loss_ce: 0.070510
# iteration 604 : loss : 0.306582, loss_ce: 0.066539
# iteration 605 : loss : 0.325643, loss_ce: 0.097906
# iteration 606 : loss : 0.290447, loss_ce: 0.055504
# iteration 607 : loss : 0.309192, loss_ce: 0.050164
# iteration 608 : loss : 0.326288, loss_ce: 0.070261
# iteration 609 : loss : 0.333828, loss_ce: 0.060888
# iteration 610 : loss : 0.404844, loss_ce: 0.036616
# iteration 611 : loss : 0.330209, loss_ce: 0.086329
# iteration 612 : loss : 0.319966, loss_ce: 0.042252
# iteration 613 : loss : 0.351206, loss_ce: 0.092233
# iteration 614 : loss : 0.348076, loss_ce: 0.120113
# iteration 615 : loss : 0.387096, loss_ce: 0.066958
# iteration 616 : loss : 0.311539, loss_ce: 0.082344
# iteration 617 : loss : 0.339976, loss_ce: 0.078730
# iteration 618 : loss : 0.318400, loss_ce: 0.104325
# iteration 619 : loss : 0.362380, loss_ce: 0.119615
# iteration 620 : loss : 0.310954, loss_ce: 0.079057
# iteration 621 : loss : 0.325421, loss_ce: 0.104968
# iteration 622 : loss : 0.297937, loss_ce: 0.079580
# iteration 623 : loss : 0.288205, loss_ce: 0.049537
# iteration 624 : loss : 0.308801, loss_ce: 0.072597
# iteration 625 : loss : 0.336588, loss_ce: 0.102690
# iteration 626 : loss : 0.311144, loss_ce: 0.063843
# iteration 627 : loss : 0.396490, loss_ce: 0.049938
# iteration 628 : loss : 0.306662, loss_ce: 0.073070
# iteration 629 : loss : 0.337693, loss_ce: 0.106600
# iteration 630 : loss : 0.355560, loss_ce: 0.069875
# iteration 631 : loss : 0.301582, loss_ce: 0.077326
# iteration 632 : loss : 0.302461, loss_ce: 0.048648
# iteration 633 : loss : 0.308149, loss_ce: 0.081066
# iteration 634 : loss : 0.305049, loss_ce: 0.080264
# iteration 635 : loss : 0.322015, loss_ce: 0.057464
# iteration 636 : loss : 0.334340, loss_ce: 0.080982
# iteration 637 : loss : 0.389099, loss_ce: 0.031546
# iteration 638 : loss : 0.308420, loss_ce: 0.043177
# iteration 639 : loss : 0.349750, loss_ce: 0.091721
# iteration 640 : loss : 0.315059, loss_ce: 0.031213
# iteration 641 : loss : 0.313940, loss_ce: 0.069873
# iteration 642 : loss : 0.308277, loss_ce: 0.068662
# iteration 643 : loss : 0.286755, loss_ce: 0.053602
# iteration 644 : loss : 0.279323, loss_ce: 0.059446
# iteration 645 : loss : 0.297834, loss_ce: 0.033813
# iteration 646 : loss : 0.283948, loss_ce: 0.054678
# iteration 647 : loss : 0.340630, loss_ce: 0.014193
# iteration 648 : loss : 0.303865, loss_ce: 0.058907
# iteration 649 : loss : 0.345643, loss_ce: 0.130787
# iteration 650 : loss : 0.303277, loss_ce: 0.042272
# iteration 651 : loss : 0.285951, loss_ce: 0.051485
# iteration 652 : loss : 0.322291, loss_ce: 0.056197
# iteration 653 : loss : 0.277653, loss_ce: 0.039080
# iteration 654 : loss : 0.320072, loss_ce: 0.071683
# iteration 655 : loss : 0.333307, loss_ce: 0.057316
# iteration 656 : loss : 0.377871, loss_ce: 0.014071
# iteration 657 : loss : 0.349229, loss_ce: 0.137259
# iteration 658 : loss : 0.375217, loss_ce: 0.042811
# iteration 659 : loss : 0.341396, loss_ce: 0.086030
# iteration 660 : loss : 0.282381, loss_ce: 0.064718
# iteration 661 : loss : 0.325040, loss_ce: 0.107889
# iteration 662 : loss : 0.318262, loss_ce: 0.065468
# iteration 663 : loss : 0.292614, loss_ce: 0.081625
# iteration 664 : loss : 0.324251, loss_ce: 0.091058
# iteration 665 : loss : 0.295251, loss_ce: 0.094787
# iteration 666 : loss : 0.350416, loss_ce: 0.034143
# iteration 667 : loss : 0.423809, loss_ce: 0.024263
# iteration 668 : loss : 0.349733, loss_ce: 0.034476
# iteration 669 : loss : 0.318415, loss_ce: 0.112143
# iteration 670 : loss : 0.309670, loss_ce: 0.101554
# iteration 671 : loss : 0.295876, loss_ce: 0.056803
# iteration 672 : loss : 0.301178, loss_ce: 0.075048
# iteration 673 : loss : 0.294413, loss_ce: 0.075860
# iteration 674 : loss : 0.282608, loss_ce: 0.091425
# iteration 675 : loss : 0.277100, loss_ce: 0.034836
# iteration 676 : loss : 0.276372, loss_ce: 0.085017
# iteration 677 : loss : 0.275885, loss_ce: 0.060537
# iteration 678 : loss : 0.320270, loss_ce: 0.037123
# iteration 679 : loss : 0.289076, loss_ce: 0.032022
# iteration 680 : loss : 0.285022, loss_ce: 0.086820
# iteration 681 : loss : 0.255238, loss_ce: 0.038942
# iteration 682 : loss : 0.311869, loss_ce: 0.040052
# iteration 683 : loss : 0.298221, loss_ce: 0.078698
# iteration 684 : loss : 0.293134, loss_ce: 0.078886
# iteration 685 : loss : 0.284104, loss_ce: 0.071432
# iteration 686 : loss : 0.276458, loss_ce: 0.032379
# iteration 687 : loss : 0.259253, loss_ce: 0.064832
# iteration 688 : loss : 0.313021, loss_ce: 0.020406
# iteration 689 : loss : 0.326573, loss_ce: 0.049826
# iteration 690 : loss : 0.353600, loss_ce: 0.024518
# iteration 691 : loss : 0.325181, loss_ce: 0.022991
# iteration 692 : loss : 0.270279, loss_ce: 0.032492
# iteration 693 : loss : 0.275919, loss_ce: 0.056670
# iteration 694 : loss : 0.282469, loss_ce: 0.037535
# iteration 695 : loss : 0.273527, loss_ce: 0.070614
# iteration 696 : loss : 0.290964, loss_ce: 0.026691
# iteration 697 : loss : 0.265127, loss_ce: 0.035345
# iteration 698 : loss : 0.245487, loss_ce: 0.046407
# iteration 699 : loss : 0.365295, loss_ce: 0.067472
# iteration 700 : loss : 0.301017, loss_ce: 0.052370
# iteration 701 : loss : 0.257282, loss_ce: 0.041836
# iteration 702 : loss : 0.295557, loss_ce: 0.050513
# iteration 703 : loss : 0.367644, loss_ce: 0.009600
# iteration 704 : loss : 0.247736, loss_ce: 0.026882
# iteration 705 : loss : 0.314268, loss_ce: 0.121022
# iteration 706 : loss : 0.256854, loss_ce: 0.050220
# iteration 707 : loss : 0.426390, loss_ce: 0.022165
# iteration 708 : loss : 0.296783, loss_ce: 0.089464
# iteration 709 : loss : 0.285100, loss_ce: 0.049119
# iteration 710 : loss : 0.354467, loss_ce: 0.054001
# iteration 711 : loss : 0.341534, loss_ce: 0.019943
# iteration 712 : loss : 0.287470, loss_ce: 0.067764
# iteration 713 : loss : 0.302284, loss_ce: 0.022164
# iteration 714 : loss : 0.251203, loss_ce: 0.052683
# iteration 715 : loss : 0.330583, loss_ce: 0.046028
# iteration 716 : loss : 0.284209, loss_ce: 0.062480
# iteration 717 : loss : 0.310027, loss_ce: 0.039085
# iteration 718 : loss : 0.257415, loss_ce: 0.033962
# iteration 719 : loss : 0.288596, loss_ce: 0.064509
# iteration 720 : loss : 0.329982, loss_ce: 0.058640
# iteration 721 : loss : 0.254385, loss_ce: 0.041555
# iteration 722 : loss : 0.282591, loss_ce: 0.068174
# iteration 723 : loss : 0.352660, loss_ce: 0.077108
# iteration 724 : loss : 0.278834, loss_ce: 0.063895
# iteration 725 : loss : 0.283262, loss_ce: 0.056864
# iteration 726 : loss : 0.343390, loss_ce: 0.045165
# iteration 727 : loss : 0.344898, loss_ce: 0.124780
# iteration 728 : loss : 0.309269, loss_ce: 0.091502
# iteration 729 : loss : 0.284247, loss_ce: 0.082446
# iteration 730 : loss : 0.293863, loss_ce: 0.075344
# iteration 731 : loss : 0.240226, loss_ce: 0.029610
# iteration 732 : loss : 0.351056, loss_ce: 0.023988
# iteration 733 : loss : 0.289269, loss_ce: 0.090075
# iteration 734 : loss : 0.295442, loss_ce: 0.060996
# iteration 735 : loss : 0.288930, loss_ce: 0.078768
# iteration 736 : loss : 0.308584, loss_ce: 0.029659
# iteration 737 : loss : 0.270749, loss_ce: 0.050254
# iteration 738 : loss : 0.274332, loss_ce: 0.042693
# iteration 739 : loss : 0.310148, loss_ce: 0.022986
# iteration 740 : loss : 0.271010, loss_ce: 0.077536
# iteration 741 : loss : 0.271455, loss_ce: 0.057374
# iteration 742 : loss : 0.399773, loss_ce: 0.023508
# iteration 743 : loss : 0.351039, loss_ce: 0.094627
# iteration 744 : loss : 0.360046, loss_ce: 0.053311
# iteration 745 : loss : 0.274011, loss_ce: 0.043369
# iteration 746 : loss : 0.367832, loss_ce: 0.023825
# iteration 747 : loss : 0.289720, loss_ce: 0.065958
# iteration 748 : loss : 0.278003, loss_ce: 0.063235
# iteration 749 : loss : 0.270580, loss_ce: 0.078432
# iteration 750 : loss : 0.325592, loss_ce: 0.121015
# iteration 751 : loss : 0.277997, loss_ce: 0.063950
# iteration 752 : loss : 0.341693, loss_ce: 0.036050
# iteration 753 : loss : 0.251225, loss_ce: 0.058569
# iteration 754 : loss : 0.265099, loss_ce: 0.044068
# iteration 755 : loss : 0.374653, loss_ce: 0.048330
# iteration 756 : loss : 0.269144, loss_ce: 0.053448
# iteration 757 : loss : 0.305005, loss_ce: 0.093137
# iteration 758 : loss : 0.275243, loss_ce: 0.033246
# iteration 759 : loss : 0.272943, loss_ce: 0.066391
# iteration 760 : loss : 0.314848, loss_ce: 0.078675
# iteration 761 : loss : 0.309811, loss_ce: 0.076463
# iteration 762 : loss : 0.436613, loss_ce: 0.019424
# iteration 763 : loss : 0.342957, loss_ce: 0.093425
# iteration 764 : loss : 0.280477, loss_ce: 0.070226
# iteration 765 : loss : 0.257826, loss_ce: 0.045466
# iteration 766 : loss : 0.267384, loss_ce: 0.021141
# iteration 767 : loss : 0.299531, loss_ce: 0.099447
# iteration 768 : loss : 0.254294, loss_ce: 0.036102
# iteration 769 : loss : 0.360358, loss_ce: 0.034337
# iteration 770 : loss : 0.315827, loss_ce: 0.117737
# iteration 771 : loss : 0.267559, loss_ce: 0.072811
# iteration 772 : loss : 0.265752, loss_ce: 0.056200
# iteration 773 : loss : 0.258873, loss_ce: 0.056726
# iteration 774 : loss : 0.276212, loss_ce: 0.052391
# iteration 775 : loss : 0.272928, loss_ce: 0.078551
# iteration 776 : loss : 0.254528, loss_ce: 0.056795
# iteration 777 : loss : 0.276873, loss_ce: 0.037318
# iteration 778 : loss : 0.255582, loss_ce: 0.054048
# iteration 779 : loss : 0.259435, loss_ce: 0.045668
# iteration 780 : loss : 0.302083, loss_ce: 0.103985
# iteration 781 : loss : 0.249977, loss_ce: 0.079816
# iteration 782 : loss : 0.292763, loss_ce: 0.029858
# iteration 783 : loss : 0.243228, loss_ce: 0.041898
# iteration 784 : loss : 0.329770, loss_ce: 0.048583
# iteration 785 : loss : 0.252627, loss_ce: 0.038340
# iteration 786 : loss : 0.257015, loss_ce: 0.038554
# iteration 787 : loss : 0.273705, loss_ce: 0.076448
# iteration 788 : loss : 0.248583, loss_ce: 0.054663
# iteration 789 : loss : 0.293580, loss_ce: 0.084960
# iteration 790 : loss : 0.265946, loss_ce: 0.061508
# iteration 791 : loss : 0.356899, loss_ce: 0.022052
# iteration 792 : loss : 0.243830, loss_ce: 0.054688
# iteration 793 : loss : 0.246708, loss_ce: 0.039288
# iteration 794 : loss : 0.253642, loss_ce: 0.055681
# iteration 795 : loss : 0.247049, loss_ce: 0.046947
# iteration 796 : loss : 0.260529, loss_ce: 0.072085
# iteration 797 : loss : 0.251643, loss_ce: 0.057013
# iteration 798 : loss : 0.260951, loss_ce: 0.074131
# iteration 799 : loss : 0.251775, loss_ce: 0.036496
# iteration 800 : loss : 0.290799, loss_ce: 0.027646
# iteration 801 : loss : 0.278079, loss_ce: 0.093158
# iteration 802 : loss : 0.345881, loss_ce: 0.029687
# iteration 803 : loss : 0.259677, loss_ce: 0.037961
# iteration 804 : loss : 0.250244, loss_ce: 0.038457
# iteration 805 : loss : 0.314635, loss_ce: 0.052778
# iteration 806 : loss : 0.339627, loss_ce: 0.057299
# iteration 807 : loss : 0.332364, loss_ce: 0.096458
# iteration 808 : loss : 0.320838, loss_ce: 0.089049
# iteration 809 : loss : 0.341350, loss_ce: 0.118589
# iteration 810 : loss : 0.286967, loss_ce: 0.059115
# iteration 811 : loss : 0.314416, loss_ce: 0.055612
# iteration 812 : loss : 0.341920, loss_ce: 0.093693
# iteration 813 : loss : 0.366984, loss_ce: 0.140197
# iteration 814 : loss : 0.312347, loss_ce: 0.084873
# iteration 815 : loss : 0.300728, loss_ce: 0.081838
# iteration 816 : loss : 0.381005, loss_ce: 0.144451
# iteration 817 : loss : 0.301913, loss_ce: 0.045817
# iteration 818 : loss : 0.350051, loss_ce: 0.027223
# iteration 819 : loss : 0.346524, loss_ce: 0.036309
# iteration 820 : loss : 0.299330, loss_ce: 0.043377
# iteration 821 : loss : 0.302026, loss_ce: 0.039204
# iteration 822 : loss : 0.288480, loss_ce: 0.029211
# iteration 823 : loss : 0.347212, loss_ce: 0.031609
# iteration 824 : loss : 0.250577, loss_ce: 0.034348
# iteration 825 : loss : 0.322106, loss_ce: 0.119679
# iteration 826 : loss : 0.330082, loss_ce: 0.127082
# iteration 827 : loss : 0.246486, loss_ce: 0.047594
# iteration 828 : loss : 0.264812, loss_ce: 0.015819
# iteration 829 : loss : 0.287550, loss_ce: 0.077429
# iteration 830 : loss : 0.280178, loss_ce: 0.067323
# iteration 831 : loss : 0.263152, loss_ce: 0.036450
#   2%|▌                            | 3/150 [18:10<14:46:31, 361.85s/it]
# iteration 832 : loss : 0.344814, loss_ce: 0.077889
# iteration 833 : loss : 0.332276, loss_ce: 0.027995
# iteration 834 : loss : 0.311177, loss_ce: 0.052084
# iteration 835 : loss : 0.282735, loss_ce: 0.052790
# iteration 836 : loss : 0.260855, loss_ce: 0.028617
# iteration 837 : loss : 0.268078, loss_ce: 0.059572
# iteration 838 : loss : 0.268584, loss_ce: 0.056803
# iteration 839 : loss : 0.281148, loss_ce: 0.060956
# iteration 840 : loss : 0.241743, loss_ce: 0.033359
# iteration 841 : loss : 0.290470, loss_ce: 0.080468
# iteration 842 : loss : 0.280356, loss_ce: 0.064018
# iteration 843 : loss : 0.226304, loss_ce: 0.036381
# iteration 844 : loss : 0.233805, loss_ce: 0.022594
# iteration 845 : loss : 0.317384, loss_ce: 0.037819
# iteration 846 : loss : 0.281766, loss_ce: 0.086623
# iteration 847 : loss : 0.258891, loss_ce: 0.053806
# iteration 848 : loss : 0.264758, loss_ce: 0.079163
# iteration 849 : loss : 0.232953, loss_ce: 0.045472
# iteration 850 : loss : 0.261446, loss_ce: 0.082291
# iteration 851 : loss : 0.231978, loss_ce: 0.030113
# iteration 852 : loss : 0.278736, loss_ce: 0.110844
# iteration 853 : loss : 0.262164, loss_ce: 0.082642
# iteration 854 : loss : 0.247189, loss_ce: 0.035988
# iteration 855 : loss : 0.363134, loss_ce: 0.040092
# iteration 856 : loss : 0.241070, loss_ce: 0.041937
# iteration 857 : loss : 0.296326, loss_ce: 0.028183
# iteration 858 : loss : 0.263643, loss_ce: 0.063710
# iteration 859 : loss : 0.332175, loss_ce: 0.019612
# iteration 860 : loss : 0.370136, loss_ce: 0.031723
# iteration 861 : loss : 0.250419, loss_ce: 0.052962
# iteration 862 : loss : 0.249249, loss_ce: 0.038408
# iteration 863 : loss : 0.252415, loss_ce: 0.066429
# iteration 864 : loss : 0.275259, loss_ce: 0.064464
# iteration 865 : loss : 0.274916, loss_ce: 0.103590
# iteration 866 : loss : 0.214841, loss_ce: 0.048427
# iteration 867 : loss : 0.248500, loss_ce: 0.072756
# iteration 868 : loss : 0.362024, loss_ce: 0.050269
# iteration 869 : loss : 0.317480, loss_ce: 0.055004
# iteration 870 : loss : 0.255022, loss_ce: 0.055609
# iteration 871 : loss : 0.289611, loss_ce: 0.057501
# iteration 872 : loss : 0.233217, loss_ce: 0.034398
# iteration 873 : loss : 0.267534, loss_ce: 0.039111
# iteration 874 : loss : 0.267999, loss_ce: 0.080335
# iteration 875 : loss : 0.237198, loss_ce: 0.039965
# iteration 876 : loss : 0.216009, loss_ce: 0.036907
# iteration 877 : loss : 0.261910, loss_ce: 0.088291
# iteration 878 : loss : 0.253123, loss_ce: 0.058034
# iteration 879 : loss : 0.248573, loss_ce: 0.036365
# iteration 880 : loss : 0.227368, loss_ce: 0.046464
# iteration 881 : loss : 0.403851, loss_ce: 0.006566
# iteration 882 : loss : 0.226269, loss_ce: 0.034576
# iteration 883 : loss : 0.244088, loss_ce: 0.060316
# iteration 884 : loss : 0.213962, loss_ce: 0.059545
# iteration 885 : loss : 0.220474, loss_ce: 0.042999
# iteration 886 : loss : 0.237947, loss_ce: 0.030884
# iteration 887 : loss : 0.282057, loss_ce: 0.018629
# iteration 888 : loss : 0.244258, loss_ce: 0.037168
# iteration 889 : loss : 0.226147, loss_ce: 0.061202
# iteration 890 : loss : 0.386156, loss_ce: 0.015931
# iteration 891 : loss : 0.259095, loss_ce: 0.085073
# iteration 892 : loss : 0.237847, loss_ce: 0.061474
# iteration 893 : loss : 0.355864, loss_ce: 0.035248
# iteration 894 : loss : 0.260763, loss_ce: 0.064826
# iteration 895 : loss : 0.246476, loss_ce: 0.053031
# iteration 896 : loss : 0.268004, loss_ce: 0.074570
# iteration 897 : loss : 0.296003, loss_ce: 0.020319
# iteration 898 : loss : 0.280019, loss_ce: 0.044205
# iteration 899 : loss : 0.314198, loss_ce: 0.065261
# iteration 900 : loss : 0.237494, loss_ce: 0.063585
# iteration 901 : loss : 0.271741, loss_ce: 0.028093
# iteration 902 : loss : 0.296000, loss_ce: 0.073739
# iteration 903 : loss : 0.340094, loss_ce: 0.022539
# iteration 904 : loss : 0.276735, loss_ce: 0.071933
# iteration 905 : loss : 0.238446, loss_ce: 0.082981
# iteration 906 : loss : 0.309438, loss_ce: 0.157865
# iteration 907 : loss : 0.284473, loss_ce: 0.086421
# iteration 908 : loss : 0.298813, loss_ce: 0.074960
# iteration 909 : loss : 0.287130, loss_ce: 0.084522
# iteration 910 : loss : 0.253807, loss_ce: 0.072850
# iteration 911 : loss : 0.240348, loss_ce: 0.042732
# iteration 912 : loss : 0.240450, loss_ce: 0.066883
# iteration 913 : loss : 0.242376, loss_ce: 0.057773
# iteration 914 : loss : 0.302906, loss_ce: 0.073140
# iteration 915 : loss : 0.418066, loss_ce: 0.013667
# iteration 916 : loss : 0.285232, loss_ce: 0.065637
# ...
# iteration 2110 : loss : 0.146981, loss_ce: 0.039685
# iteration 2111 : loss : 0.148521, loss_ce: 0.015924
# iteration 2112 : loss : 0.269770, loss_ce: 0.022549
# iteration 2113 : loss : 0.133943, loss_ce: 0.047708
# iteration 2114 : loss : 0.095857, loss_ce: 0.036205
# iteration 2115 : loss : 0.154239, loss_ce: 0.052975
# iteration 2116 : loss : 0.115111, loss_ce: 0.042356
# iteration 2117 : loss : 0.138822, loss_ce: 0.025797
# iteration 2118 : loss : 0.114890, loss_ce: 0.041295
# iteration 2119 : loss : 0.127274, loss_ce: 0.024883
# iteration 2120 : loss : 0.140108, loss_ce: 0.064221
# iteration 2121 : loss : 0.124132, loss_ce: 0.020684
# iteration 2122 : loss : 0.199632, loss_ce: 0.021712
# iteration 2123 : loss : 0.249468, loss_ce: 0.011261
# iteration 2124 : loss : 0.132366, loss_ce: 0.026191
# iteration 2125 : loss : 0.250239, loss_ce: 0.026440
# iteration 2126 : loss : 0.136922, loss_ce: 0.039232
# iteration 2127 : loss : 0.159020, loss_ce: 0.038587
# iteration 2128 : loss : 0.162049, loss_ce: 0.047287
# iteration 2129 : loss : 0.341767, loss_ce: 0.003282
# iteration 2130 : loss : 0.140337, loss_ce: 0.055167
# iteration 2131 : loss : 0.092432, loss_ce: 0.056386
# iteration 2132 : loss : 0.080702, loss_ce: 0.021823
# iteration 2133 : loss : 0.082383, loss_ce: 0.027799
# iteration 2134 : loss : 0.125343, loss_ce: 0.029603
# iteration 2135 : loss : 0.196949, loss_ce: 0.019649
# iteration 2136 : loss : 0.277668, loss_ce: 0.010376
# iteration 2137 : loss : 0.112457, loss_ce: 0.027920
# iteration 2138 : loss : 0.103443, loss_ce: 0.029547
# iteration 2139 : loss : 0.158872, loss_ce: 0.016772
# iteration 2140 : loss : 0.095839, loss_ce: 0.024552
# iteration 2141 : loss : 0.147267, loss_ce: 0.013415
# iteration 2142 : loss : 0.115694, loss_ce: 0.026819
# iteration 2143 : loss : 0.085469, loss_ce: 0.039289
# iteration 2144 : loss : 0.192800, loss_ce: 0.012109
# iteration 2145 : loss : 0.159912, loss_ce: 0.015255
# iteration 2146 : loss : 0.085179, loss_ce: 0.027477
# iteration 2147 : loss : 0.112905, loss_ce: 0.042998
# iteration 2148 : loss : 0.144887, loss_ce: 0.016500
# iteration 2149 : loss : 0.097997, loss_ce: 0.035883
# iteration 2150 : loss : 0.105461, loss_ce: 0.061359
# iteration 2151 : loss : 0.293216, loss_ce: 0.007599
# iteration 2152 : loss : 0.143463, loss_ce: 0.032030
# iteration 2153 : loss : 0.139895, loss_ce: 0.067162
# iteration 2154 : loss : 0.136125, loss_ce: 0.033617
# iteration 2155 : loss : 0.243684, loss_ce: 0.016781
# iteration 2156 : loss : 0.215122, loss_ce: 0.013006
# iteration 2157 : loss : 0.162555, loss_ce: 0.042807
# iteration 2158 : loss : 0.171058, loss_ce: 0.048093
# iteration 2159 : loss : 0.090504, loss_ce: 0.018186
# iteration 2160 : loss : 0.101473, loss_ce: 0.019785
# iteration 2161 : loss : 0.264571, loss_ce: 0.039387
# iteration 2162 : loss : 0.445911, loss_ce: 0.002951
# iteration 2163 : loss : 0.135194, loss_ce: 0.035037
# iteration 2164 : loss : 0.098788, loss_ce: 0.018790
# iteration 2165 : loss : 0.149742, loss_ce: 0.023223
# iteration 2166 : loss : 0.106271, loss_ce: 0.031807
# iteration 2167 : loss : 0.107446, loss_ce: 0.022434
# iteration 2168 : loss : 0.110065, loss_ce: 0.020401
# iteration 2169 : loss : 0.117835, loss_ce: 0.023173
# iteration 2170 : loss : 0.149085, loss_ce: 0.009184
# iteration 2171 : loss : 0.175622, loss_ce: 0.012453
# iteration 2172 : loss : 0.089127, loss_ce: 0.023444
# iteration 2173 : loss : 0.086215, loss_ce: 0.019803
# iteration 2174 : loss : 0.131913, loss_ce: 0.078517
# iteration 2175 : loss : 0.248959, loss_ce: 0.019561
# iteration 2176 : loss : 0.131365, loss_ce: 0.037689
# iteration 2177 : loss : 0.166502, loss_ce: 0.040907
# iteration 2178 : loss : 0.152384, loss_ce: 0.031546
# iteration 2179 : loss : 0.206364, loss_ce: 0.025847
# iteration 2180 : loss : 0.102758, loss_ce: 0.017487
# iteration 2181 : loss : 0.160952, loss_ce: 0.021857
# iteration 2182 : loss : 0.168612, loss_ce: 0.021708
# iteration 2183 : loss : 0.161890, loss_ce: 0.012820
# iteration 2184 : loss : 0.117832, loss_ce: 0.043884
# iteration 2185 : loss : 0.102529, loss_ce: 0.034612
# iteration 2186 : loss : 0.187769, loss_ce: 0.021445
# iteration 2187 : loss : 0.146873, loss_ce: 0.017516
# iteration 2188 : loss : 0.230729, loss_ce: 0.024937
# iteration 2189 : loss : 0.170724, loss_ce: 0.020369
# iteration 2190 : loss : 0.152038, loss_ce: 0.017301
# iteration 2191 : loss : 0.101452, loss_ce: 0.049624
# iteration 2192 : loss : 0.150628, loss_ce: 0.050519
# iteration 2193 : loss : 0.163170, loss_ce: 0.039504
# iteration 2194 : loss : 0.120845, loss_ce: 0.051743
# iteration 2195 : loss : 0.121174, loss_ce: 0.046477
# iteration 2196 : loss : 0.095235, loss_ce: 0.024906
# iteration 2197 : loss : 0.275296, loss_ce: 0.021523
# iteration 2198 : loss : 0.084305, loss_ce: 0.046386
# iteration 2199 : loss : 0.398405, loss_ce: 0.002842
# iteration 2200 : loss : 0.159543, loss_ce: 0.038395
# iteration 2201 : loss : 0.126868, loss_ce: 0.030399
# iteration 2202 : loss : 0.214269, loss_ce: 0.025609
# iteration 2203 : loss : 0.104663, loss_ce: 0.032851
# iteration 2204 : loss : 0.215256, loss_ce: 0.014245
# iteration 2205 : loss : 0.062912, loss_ce: 0.029645
# iteration 2206 : loss : 0.133711, loss_ce: 0.087834
# iteration 2207 : loss : 0.087379, loss_ce: 0.035371
# iteration 2208 : loss : 0.095482, loss_ce: 0.037271
# iteration 2209 : loss : 0.271471, loss_ce: 0.024388
# iteration 2210 : loss : 0.088002, loss_ce: 0.038267
# iteration 2211 : loss : 0.081846, loss_ce: 0.033359
# iteration 2212 : loss : 0.219882, loss_ce: 0.008189
# iteration 2213 : loss : 0.120819, loss_ce: 0.035013
# iteration 2214 : loss : 0.133969, loss_ce: 0.009588
# iteration 2215 : loss : 0.120944, loss_ce: 0.022529
# iteration 2216 : loss : 0.328493, loss_ce: 0.014032
#   5%|█▌                           | 8/150 [48:11<14:14:59, 361.27s/it]
# iteration 2217 : loss : 0.130563, loss_ce: 0.020448
# iteration 2218 : loss : 0.130422, loss_ce: 0.037639
# iteration 2219 : loss : 0.097062, loss_ce: 0.047478
# iteration 2220 : loss : 0.119543, loss_ce: 0.026013
# iteration 2221 : loss : 0.135185, loss_ce: 0.017567
# iteration 2222 : loss : 0.161835, loss_ce: 0.026732
# iteration 2223 : loss : 0.078551, loss_ce: 0.035972
# iteration 2224 : loss : 0.159665, loss_ce: 0.028016
# iteration 2225 : loss : 0.066221, loss_ce: 0.022965
# iteration 2226 : loss : 0.112421, loss_ce: 0.029219
# iteration 2227 : loss : 0.100601, loss_ce: 0.045959
# iteration 2228 : loss : 0.085682, loss_ce: 0.039538
# iteration 2229 : loss : 0.159698, loss_ce: 0.023254
# iteration 2230 : loss : 0.087791, loss_ce: 0.043904
# iteration 2231 : loss : 0.092048, loss_ce: 0.025973
# iteration 2232 : loss : 0.083607, loss_ce: 0.033191
# iteration 2233 : loss : 0.123139, loss_ce: 0.010933
# iteration 2234 : loss : 0.162274, loss_ce: 0.021552
# iteration 2235 : loss : 0.093291, loss_ce: 0.025079
# iteration 2236 : loss : 0.131088, loss_ce: 0.029748
# iteration 2237 : loss : 0.079448, loss_ce: 0.017370
# iteration 2238 : loss : 0.150990, loss_ce: 0.018488
# iteration 2239 : loss : 0.386102, loss_ce: 0.006456
# iteration 2240 : loss : 0.255243, loss_ce: 0.043669
# iteration 2241 : loss : 0.096507, loss_ce: 0.029539
# iteration 2242 : loss : 0.101545, loss_ce: 0.053256
# iteration 2243 : loss : 0.127086, loss_ce: 0.013966
# iteration 2244 : loss : 0.139344, loss_ce: 0.028838
# iteration 2245 : loss : 0.127805, loss_ce: 0.017075
# iteration 2246 : loss : 0.100112, loss_ce: 0.012487
# iteration 2247 : loss : 0.068788, loss_ce: 0.017989
# iteration 2248 : loss : 0.104576, loss_ce: 0.025456
# iteration 2249 : loss : 0.158116, loss_ce: 0.007797
# iteration 2250 : loss : 0.174315, loss_ce: 0.018068
# iteration 2251 : loss : 0.126183, loss_ce: 0.029529
# iteration 2252 : loss : 0.080213, loss_ce: 0.047747
# iteration 2253 : loss : 0.076114, loss_ce: 0.029149
# iteration 2254 : loss : 0.140705, loss_ce: 0.015994
# iteration 2255 : loss : 0.118464, loss_ce: 0.048174
# iteration 2256 : loss : 0.124541, loss_ce: 0.029609
# iteration 2257 : loss : 0.153439, loss_ce: 0.022635
# iteration 2258 : loss : 0.266904, loss_ce: 0.013312
# iteration 2259 : loss : 0.096013, loss_ce: 0.026784
# iteration 2260 : loss : 0.144235, loss_ce: 0.024759
# iteration 2261 : loss : 0.154499, loss_ce: 0.019315
# iteration 2262 : loss : 0.129974, loss_ce: 0.033333
# iteration 2263 : loss : 0.132510, loss_ce: 0.029370
# iteration 2264 : loss : 0.134492, loss_ce: 0.022829
# iteration 2265 : loss : 0.095973, loss_ce: 0.044374
# iteration 2266 : loss : 0.145425, loss_ce: 0.030798
# iteration 2267 : loss : 0.176290, loss_ce: 0.037606
# iteration 2268 : loss : 0.129082, loss_ce: 0.012243
# iteration 2269 : loss : 0.199921, loss_ce: 0.008304
# iteration 2270 : loss : 0.088396, loss_ce: 0.014960
# iteration 2271 : loss : 0.192642, loss_ce: 0.026056
# iteration 2272 : loss : 0.159690, loss_ce: 0.050960
# iteration 2273 : loss : 0.122660, loss_ce: 0.022253
# iteration 2274 : loss : 0.170352, loss_ce: 0.029613
# iteration 2275 : loss : 0.258976, loss_ce: 0.017816
# iteration 2276 : loss : 0.167093, loss_ce: 0.035084
# iteration 2277 : loss : 0.237859, loss_ce: 0.018563
# iteration 2278 : loss : 0.116198, loss_ce: 0.040584
# iteration 2279 : loss : 0.244576, loss_ce: 0.018439
# iteration 2280 : loss : 0.160063, loss_ce: 0.021912
# iteration 2281 : loss : 0.114997, loss_ce: 0.051603
# iteration 2282 : loss : 0.149604, loss_ce: 0.023933
# iteration 2283 : loss : 0.116297, loss_ce: 0.015851
# iteration 2284 : loss : 0.087265, loss_ce: 0.039190
# iteration 2285 : loss : 0.173562, loss_ce: 0.024220
# iteration 2286 : loss : 0.305965, loss_ce: 0.015847
# iteration 2287 : loss : 0.185589, loss_ce: 0.037046
# iteration 2288 : loss : 0.103680, loss_ce: 0.037199
# iteration 2289 : loss : 0.099200, loss_ce: 0.018113
# iteration 2290 : loss : 0.164677, loss_ce: 0.025870
# iteration 2291 : loss : 0.157699, loss_ce: 0.015682
# iteration 2292 : loss : 0.112854, loss_ce: 0.030878
# iteration 2293 : loss : 0.248264, loss_ce: 0.014414
# iteration 2294 : loss : 0.145647, loss_ce: 0.031093
# iteration 2295 : loss : 0.109705, loss_ce: 0.030661
# iteration 2296 : loss : 0.294159, loss_ce: 0.014404
# iteration 2297 : loss : 0.132724, loss_ce: 0.014879
# iteration 2298 : loss : 0.165841, loss_ce: 0.046141
# iteration 2299 : loss : 0.248837, loss_ce: 0.020553
# iteration 2300 : loss : 0.150157, loss_ce: 0.046687
# iteration 2301 : loss : 0.150472, loss_ce: 0.025449
# iteration 2302 : loss : 0.242842, loss_ce: 0.012617
# iteration 2303 : loss : 0.393062, loss_ce: 0.001286
# iteration 2304 : loss : 0.132890, loss_ce: 0.033977
# iteration 2305 : loss : 0.184123, loss_ce: 0.024187
# iteration 2306 : loss : 0.115240, loss_ce: 0.026423
# iteration 2307 : loss : 0.153049, loss_ce: 0.038286
# iteration 2308 : loss : 0.116134, loss_ce: 0.013537
# iteration 2309 : loss : 0.122762, loss_ce: 0.034439
# iteration 2310 : loss : 0.114588, loss_ce: 0.013362
# iteration 2311 : loss : 0.111244, loss_ce: 0.018807
# iteration 2312 : loss : 0.162436, loss_ce: 0.022748
# iteration 2313 : loss : 0.104111, loss_ce: 0.041757
# iteration 2314 : loss : 0.058690, loss_ce: 0.022135
# iteration 2315 : loss : 0.158356, loss_ce: 0.062858
# iteration 2316 : loss : 0.138141, loss_ce: 0.049274
# iteration 2317 : loss : 0.121337, loss_ce: 0.022098
# iteration 2318 : loss : 0.123161, loss_ce: 0.029884
# iteration 2319 : loss : 0.091563, loss_ce: 0.038262
# iteration 2320 : loss : 0.088532, loss_ce: 0.027015
# iteration 2321 : loss : 0.085578, loss_ce: 0.018804
# iteration 2322 : loss : 0.128582, loss_ce: 0.030584
# iteration 2323 : loss : 0.115984, loss_ce: 0.032140
# iteration 2324 : loss : 0.127044, loss_ce: 0.036607
# iteration 2325 : loss : 0.185123, loss_ce: 0.028137
# iteration 2326 : loss : 0.182523, loss_ce: 0.022918
# iteration 2327 : loss : 0.086051, loss_ce: 0.027415
# iteration 2328 : loss : 0.154181, loss_ce: 0.029777
# iteration 2329 : loss : 0.077323, loss_ce: 0.036809
# iteration 2330 : loss : 0.087416, loss_ce: 0.033398
# iteration 2331 : loss : 0.090460, loss_ce: 0.028431
# iteration 2332 : loss : 0.248049, loss_ce: 0.009998
# iteration 2333 : loss : 0.113963, loss_ce: 0.009203
# iteration 2334 : loss : 0.155623, loss_ce: 0.019331
# iteration 2335 : loss : 0.065184, loss_ce: 0.019855
# iteration 2336 : loss : 0.064400, loss_ce: 0.019211
# iteration 2337 : loss : 0.186029, loss_ce: 0.006434
# iteration 2338 : loss : 0.163556, loss_ce: 0.015829
#   5%|█▌                           | 8/150 [50:52<15:03:01, 381.56s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-6a3eb4ab29a3> in <module>()
#      94
#      95     trainer = {'Synapse': trainer_synapse,}
# ---> 96     trainer[dataset_name](args, net, snapshot_path)
#
# <ipython-input-26-7f78be076262> in trainer_synapse(args, model, snapshot_path)
#      53             image_batch, label_batch = sampled_batch['image'], sampled_batch['label']
#      54             image_batch, label_batch = image_batch.cuda(), label_batch.cuda()
# ---> 55             outputs = model(image_batch)
#      56             loss_ce = ce_loss(outputs, label_batch[:].long())
#      57             loss_dice = dice_loss(outputs, label_batch, softmax=True)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-23-2b47a0c60dac> in forward(self, x)
#     384         if x.size()[1] == 1:
#     385             x = x.repeat(1,3,1,1)
# --> 386         x, attn_weights, features = self.transformer(x)  # (B, n_patch, hidden)
#     387         x = self.decoder(x, features)
#     388         logits = self.segmentation_head(x)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-23-2b47a0c60dac> in forward(self, input_ids)
#     251     def forward(self, input_ids):
#     252         embedding_output, features = self.embeddings(input_ids)
# --> 253         encoded, attn_weights = self.encoder(embedding_output)  # (B, n_patch, hidden)
#     254         return encoded, attn_weights, features
#     255
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-23-2b47a0c60dac> in forward(self, hidden_states)
#     236         attn_weights = []
#     237         for layer_block in self.layer:
# --> 238             hidden_states, weights = layer_block(hidden_states)
#     239             if self.vis:
#     240                 attn_weights.append(weights)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-23-2b47a0c60dac> in forward(self, x)
#     183         x = self.ffn(x)
#     184         x = x + h
# --> 185         return x, weights
#     186
#     187     def load_from(self, weights, n_block):
#
# KeyboardInterrupt:
